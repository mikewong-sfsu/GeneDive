# %% [markdown]
# # Alternative ID Generation Script
#
# This will produce all the various IDs that can be used to lookup in different databases.

# %%
# Progress Bar I found on the internet.
# https://github.com/alexanderkuk/log-progress
from progress_bar import log_progress
import re
import sqlite3
import json
from shutil import copy2

# %%
WRITE = True
DROP_AND_REMAKE = True

# TSV files containing Pharm-GKB data
PHARMGKB_INTERACTIONS_FILE          = 'tsv_data/pharmgkb/relationships.tsv'
PHARMGKB_CHEMICAL_IDS_FILE          = 'tsv_data/pharmgkb/ids/chemicals.tsv'
PHARMGKB_DRUGS_IDS_FILE             = 'tsv_data/pharmgkb/ids/drugs.tsv'
PHARMGKB_GENES_IDS_FILE             = 'tsv_data/pharmgkb/ids/genes.tsv'
PHARMGKB_PHENOTYPES_IDS_FILE        = 'tsv_data/pharmgkb/ids/phenotypes.tsv'

PHARMGKB_ID_FILES = [
     {"filename":PHARMGKB_CHEMICAL_IDS_FILE},
     {"filename":PHARMGKB_DRUGS_IDS_FILE},
    {"filename":PHARMGKB_GENES_IDS_FILE},
     {"filename":PHARMGKB_PHENOTYPES_IDS_FILE},
]

TABLE_NAME = "alternative_ids"
MESH_VALUE = "mesh"
PHARMGKB_VALUE = "pgkb"
NCBI_VALUE = "ncbi"
VALUES_COLUMN = "vals"
TYPE_COLUMN = "type"
DROP_SQL = 'DROP TABLE IF EXISTS {table};'.format(table = TABLE_NAME)
SCHEMA = '''CREATE TABLE IF NOT EXISTS {table} (
            {col1} VARCHAR UNIQUE,
            {col2} VARCHAR UNIQUE,
            {col3} VARCHAR UNIQUE,
            {col4} VARCHAR,
            {col5} VARCHAR,
            PRIMARY KEY ({col1}, {col2}, {col3})
            );'''.format(
            table = TABLE_NAME, 
            col1=MESH_VALUE,
            col2=PHARMGKB_VALUE,
            col3=NCBI_VALUE,
            col4=VALUES_COLUMN,
            col5=TYPE_COLUMN)
QUERY_UNIQUE_IDS = '''  SELECT DISTINCT geneids1,
                        {type_col}1 FROM interactions
                            union
                        SELECT DISTINCT geneids2,
                        {type_col}2 FROM interactions;'''.format(type_col = TYPE_COLUMN)

PLOS_PMC_DB = 'sqlite_data/data.plos-pmc.sqlite'
ALL_DB = 'sqlite_data/data.all.sqlite'



DELIMITER = "\t"

# %% [markdown]
# ### Connect to Databases

# %%
conn_all = sqlite3.connect(ALL_DB)
cursor_all = conn_all.cursor()

# %% [markdown]
# ### Create table

# %%
if DROP_AND_REMAKE:
    cursor_all.execute(DROP_SQL)
cursor_all.execute(SCHEMA)

# %% [markdown]
# ### Gather Unique IDs into Hash Map
# The index is the id, the value is an object.

# %%
data = {}

print("Executing SQL query. May take a minute.")
cursor = cursor_all.execute(QUERY_UNIQUE_IDS)
interactions = cursor.fetchall()
print("Query complete")

for row in log_progress(interactions, every=100, name="IDs added"):

    if row == None:
        continue

    
    id = row[0]
    dgr_type = row[1]

    if id not in data:
        data[id] = { TYPE_COLUMN : dgr_type}
        
print("Unique IDs added to data")
# Out:
# Executing SQL query. May take a minute.
# Query complete
# VBox(children=(HTML(value=''), IntProgress(value=0, max=29881)))
# Unique IDs added to data

# %% [markdown]
# ## Create lookup table for other values

# %%
id_map = {}

for id_file in PHARMGKB_ID_FILES:
    with open(id_file["filename"]) as file:
        try:
            header = None
            linenum = 0
            for line in file:
                linenum+=1
                pgkb = None
                ncbi = None
                mesh = None

                # deliminate the lines
                line = line.strip().split(DELIMITER)

                # Read the headers of the file and assign them to a dictionary {column_name: column_number}
                if linenum == 1:
                    header = {name.strip(): col for col, name in enumerate(line)}
                    print(header)                    
                    continue

                


                # set variables
                pgkb = line[header["PharmGKB Accession Id"]]

                if "NCBI Gene ID" in header:
                    ncbi = line[header["NCBI Gene ID"]]
                if 'External Vocabulary'in header:
                    if len(line) > header['External Vocabulary']: # If a line doesn't have data on the end, it wont be in the delimination
                        external = str(line[header['External Vocabulary']]).replace('"', "") # weird bug where quotes break regex
                        match = re.match('MESH:[0-9A-Za-z]+',external,re.IGNORECASE)
                        if match != None:
                            mesh = match.group(0).upper()

                # fill map   
                values = {PHARMGKB_VALUE: pgkb}                
                if ncbi is not None:
                    values[NCBI_VALUE] = ncbi
                if mesh is not None:
                    values[MESH_VALUE] = mesh
        
                id_map[pgkb] = values
                
                if ncbi is not None:
                    id_map[ncbi] = values
                if mesh is not None:
                    id_map[mesh] = values
                

        except Exception as e:
            print(line)
            raise e
# Out:
# {'PharmGKB Accession Id': 0, 'Name': 1, 'Generic Names': 2, 'Trade Names': 3, 'Brand Mixtures': 4, 'Type': 5, 'Cross-references': 6, 'SMILES': 7, 'InChI': 8, 'Dosing Guideline': 9, 'External Vocabulary': 10, 'Clinical Annotation Count': 11, 'Variant Annotation Count': 12, 'Pathway Count': 13, 'VIP Count': 14, 'Dosing Guideline Sources': 15, 'Top Clinical Annotation Level': 16, 'Top FDA Label Testing Level': 17, 'Top Any Drug Label Testing Level': 18, 'Label Has Dosing Info': 19, 'Has Rx Annotation': 20}
# {'PharmGKB Accession Id': 0, 'Name': 1, 'Generic Names': 2, 'Trade Names': 3, 'Brand Mixtures': 4, 'Type': 5, 'Cross-references': 6, 'SMILES': 7, 'InChI': 8, 'Dosing Guideline': 9, 'External Vocabulary': 10, 'Clinical Annotation Count': 11, 'Variant Annotation Count': 12, 'Pathway Count': 13, 'VIP Count': 14, 'Dosing Guideline Sources': 15, 'Top Clinical Annotation Level': 16, 'Top FDA Label Testing Level': 17, 'Top Any Drug Label Testing Level': 18, 'Label Has Dosing Info': 19, 'Has Rx Annotation': 20}
# {'PharmGKB Accession Id': 0, 'NCBI Gene ID': 1, 'HGNC ID': 2, 'Ensembl Id': 3, 'Name': 4, 'Symbol': 5, 'Alternate Names': 6, 'Alternate Symbols': 7, 'Is VIP': 8, 'Has Variant Annotation': 9, 'Cross-references': 10, 'Has CPIC Dosing Guideline': 11, 'Chromosome': 12, 'Chromosomal Start - GRCh37.p13': 13, 'Chromosomal Stop - GRCh37.p13': 14, 'Chromosomal Start - GRCh38.p7': 15, 'Chromosomal Stop - GRCh38.p7': 16}
# {'PharmGKB Accession Id': 0, 'Name': 1, 'Alternate Names': 2, 'Cross-references': 3, 'External Vocabulary': 4}

# %%
# Just to test
print(json.dumps(data['1000']))
# Out:
# {"type": "Gene"}

# %% [markdown]
# ### Go through each ID and find all alternative values

# %%
def getType(string):
    if string[:2] in 'PA':
        return PHARMGKB_VALUE
    elif string[:5] in 'MESH:':
        return MESH_VALUE
    else:
        return NCBI_VALUE

count = 0
for value in log_progress(data, every=1000, name="IDs looked up "):

    try:
        ncbi_value = None
        pharmgkb_value = None
        mesh_value = None

        data_values = data.values()
        
        # Get ID type
        if value in id_map:
            map_data = id_map[value]
        

            # Lookup NCBI
            if NCBI_VALUE in map_data:
                ncbi_value = map_data[NCBI_VALUE]
                data[value][NCBI_VALUE] = ncbi_value

            # lookup PharmGKB
            if PHARMGKB_VALUE in map_data:
                pharmgkb_value = map_data[PHARMGKB_VALUE]
                data[value][PHARMGKB_VALUE] = pharmgkb_value

            # Lookup MESH
            if MESH_VALUE in map_data:
                mesh_value = map_data[MESH_VALUE]
                data[value][MESH_VALUE] = mesh_value

        if value not in data_values:
            data[value][getType(value)] = value
            # print(value, data[value])

        # If no alias found
        if len(data[value]) == 2:
            print(value, data[value])
        else:
            count+=1
    except Exception as e:
        print(value, str(e))
    

print("Total with aliases:", count, "/", len(data))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=29354)))
# 100529141 {'type': 'Gene', 'ncbi': '100529141'}
# 155060 {'type': 'Gene', 'ncbi': '155060'}
# 339010 {'type': 'Gene', 'ncbi': '339010'}
# 441330 {'type': 'Gene', 'ncbi': '441330'}
# 641590 {'type': 'Gene', 'ncbi': '641590'}
# 654341 {'type': 'Gene', 'ncbi': '654341'}
# 85295 {'type': 'Gene', 'ncbi': '85295'}
# Haplotype for PA128 {'type': 'VariantLocation', 'ncbi': 'Haplotype for PA128'}
# Haplotype for PA166 {'type': 'VariantLocation', 'ncbi': 'Haplotype for PA166'}
# Haplotype for PA356 {'type': 'VariantLocation', 'ncbi': 'Haplotype for PA356'}
# MESH:C531600 {'type': 'Disease', 'mesh': 'MESH:C531600'}
# MESH:C531616 {'type': 'Disease', 'mesh': 'MESH:C531616'}
# MESH:C531617 {'type': 'Disease', 'mesh': 'MESH:C531617'}
# MESH:C531621 {'type': 'Disease', 'mesh': 'MESH:C531621'}
# MESH:C531625 {'type': 'Disease', 'mesh': 'MESH:C531625'}
# MESH:C531673 {'type': 'Disease', 'mesh': 'MESH:C531673'}
# MESH:C531736 {'type': 'Disease', 'mesh': 'MESH:C531736'}
# MESH:C531760 {'type': 'Disease', 'mesh': 'MESH:C531760'}
# MESH:C531762 {'type': 'Disease', 'mesh': 'MESH:C531762'}
# MESH:C531777 {'type': 'Disease', 'mesh': 'MESH:C531777'}
# MESH:C531816 {'type': 'Disease', 'mesh': 'MESH:C531816'}
# MESH:C531835 {'type': 'Disease', 'mesh': 'MESH:C531835'}
# MESH:C531844 {'type': 'Disease', 'mesh': 'MESH:C531844'}
# MESH:C535282 {'type': 'Disease', 'mesh': 'MESH:C535282'}
# MESH:C535288 {'type': 'Disease', 'mesh': 'MESH:C535288'}
# MESH:C535289 {'type': 'Disease', 'mesh': 'MESH:C535289'}
# MESH:C535297 {'type': 'Disease', 'mesh': 'MESH:C535297'}
# MESH:C535308 {'type': 'Disease', 'mesh': 'MESH:C535308'}
# MESH:C535310 {'type': 'Disease', 'mesh': 'MESH:C535310'}
# MESH:C535311 {'type': 'Disease', 'mesh': 'MESH:C535311'}
# MESH:C535314 {'type': 'Disease', 'mesh': 'MESH:C535314'}
# MESH:C535318 {'type': 'Disease', 'mesh': 'MESH:C535318'}
# MESH:C535326 {'type': 'Disease', 'mesh': 'MESH:C535326'}
# MESH:C535331 {'type': 'Disease', 'mesh': 'MESH:C535331'}
# MESH:C535338 {'type': 'Disease', 'mesh': 'MESH:C535338'}
# MESH:C535342 {'type': 'Disease', 'mesh': 'MESH:C535342'}
# MESH:C535358 {'type': 'Disease', 'mesh': 'MESH:C535358'}
# MESH:C535372 {'type': 'Disease', 'mesh': 'MESH:C535372'}
# MESH:C535377 {'type': 'Disease', 'mesh': 'MESH:C535377'}
# MESH:C535380 {'type': 'Disease', 'mesh': 'MESH:C535380'}
# MESH:C535382 {'type': 'Disease', 'mesh': 'MESH:C535382'}
# MESH:C535396 {'type': 'Disease', 'mesh': 'MESH:C535396'}
# MESH:C535397 {'type': 'Disease', 'mesh': 'MESH:C535397'}
# MESH:C535413 {'type': 'Disease', 'mesh': 'MESH:C535413'}
# MESH:C535416 {'type': 'Disease', 'mesh': 'MESH:C535416'}
# MESH:C535417 {'type': 'Disease', 'mesh': 'MESH:C535417'}
# MESH:C535418 {'type': 'Disease', 'mesh': 'MESH:C535418'}
# MESH:C535431 {'type': 'Disease', 'mesh': 'MESH:C535431'}
# MESH:C535434 {'type': 'Disease', 'mesh': 'MESH:C535434'}
# MESH:C535436 {'type': 'Disease', 'mesh': 'MESH:C535436'}
# MESH:C535440 {'type': 'Disease', 'mesh': 'MESH:C535440'}
# MESH:C535456 {'type': 'Disease', 'mesh': 'MESH:C535456'}
# MESH:C535460 {'type': 'Disease', 'mesh': 'MESH:C535460'}
# MESH:C535463 {'type': 'Disease', 'mesh': 'MESH:C535463'}
# MESH:C535466 {'type': 'Disease', 'mesh': 'MESH:C535466'}
# MESH:C535473 {'type': 'Disease', 'mesh': 'MESH:C535473'}
# MESH:C535474 {'type': 'Disease', 'mesh': 'MESH:C535474'}
# MESH:C535475 {'type': 'Disease', 'mesh': 'MESH:C535475'}
# MESH:C535476 {'type': 'Disease', 'mesh': 'MESH:C535476'}
# MESH:C535477 {'type': 'Disease', 'mesh': 'MESH:C535477'}
# MESH:C535480 {'type': 'Disease', 'mesh': 'MESH:C535480'}
# MESH:C535483 {'type': 'Disease', 'mesh': 'MESH:C535483'}
# MESH:C535484 {'type': 'Disease', 'mesh': 'MESH:C535484'}
# MESH:C535494 {'type': 'Disease', 'mesh': 'MESH:C535494'}
# MESH:C535500 {'type': 'Disease', 'mesh': 'MESH:C535500'}
# MESH:C535506 {'type': 'Disease', 'mesh': 'MESH:C535506'}
# MESH:C535507 {'type': 'Disease', 'mesh': 'MESH:C535507'}
# MESH:C535509 {'type': 'Disease', 'mesh': 'MESH:C535509'}
# MESH:C535516 {'type': 'Disease', 'mesh': 'MESH:C535516'}
# MESH:C535523 {'type': 'Disease', 'mesh': 'MESH:C535523'}
# MESH:C535526 {'type': 'Disease', 'mesh': 'MESH:C535526'}
# MESH:C535531 {'type': 'Disease', 'mesh': 'MESH:C535531'}
# MESH:C535533 {'type': 'Disease', 'mesh': 'MESH:C535533'}
# MESH:C535536 {'type': 'Disease', 'mesh': 'MESH:C535536'}
# MESH:C535540 {'type': 'Disease', 'mesh': 'MESH:C535540'}
# MESH:C535553 {'type': 'Disease', 'mesh': 'MESH:C535553'}
# MESH:C535555 {'type': 'Disease', 'mesh': 'MESH:C535555'}
# MESH:C535566 {'type': 'Disease', 'mesh': 'MESH:C535566'}
# MESH:C535568 {'type': 'Disease', 'mesh': 'MESH:C535568'}
# MESH:C535572 {'type': 'Disease', 'mesh': 'MESH:C535572'}
# MESH:C535575 {'type': 'Disease', 'mesh': 'MESH:C535575'}
# MESH:C535579 {'type': 'Disease', 'mesh': 'MESH:C535579'}
# MESH:C535589 {'type': 'Disease', 'mesh': 'MESH:C535589'}
# MESH:C535598 {'type': 'Disease', 'mesh': 'MESH:C535598'}
# MESH:C535601 {'type': 'Disease', 'mesh': 'MESH:C535601'}
# MESH:C535602 {'type': 'Disease', 'mesh': 'MESH:C535602'}
# MESH:C535607 {'type': 'Disease', 'mesh': 'MESH:C535607'}
# MESH:C535627 {'type': 'Disease', 'mesh': 'MESH:C535627'}
# MESH:C535648 {'type': 'Disease', 'mesh': 'MESH:C535648'}
# MESH:C535658 {'type': 'Disease', 'mesh': 'MESH:C535658'}
# MESH:C535668 {'type': 'Disease', 'mesh': 'MESH:C535668'}
# MESH:C535679 {'type': 'Disease', 'mesh': 'MESH:C535679'}
# MESH:C535683 {'type': 'Disease', 'mesh': 'MESH:C535683'}
# MESH:C535684 {'type': 'Disease', 'mesh': 'MESH:C535684'}
# MESH:C535687 {'type': 'Disease', 'mesh': 'MESH:C535687'}
# MESH:C535689 {'type': 'Disease', 'mesh': 'MESH:C535689'}
# MESH:C535690 {'type': 'Disease', 'mesh': 'MESH:C535690'}
# MESH:C535700 {'type': 'Disease', 'mesh': 'MESH:C535700'}
# MESH:C535718 {'type': 'Disease', 'mesh': 'MESH:C535718'}
# MESH:C535720 {'type': 'Disease', 'mesh': 'MESH:C535720'}
# MESH:C535729 {'type': 'Disease', 'mesh': 'MESH:C535729'}
# MESH:C535735 {'type': 'Disease', 'mesh': 'MESH:C535735'}
# MESH:C535737 {'type': 'Disease', 'mesh': 'MESH:C535737'}
# MESH:C535739 {'type': 'Disease', 'mesh': 'MESH:C535739'}
# MESH:C535758 {'type': 'Disease', 'mesh': 'MESH:C535758'}
# MESH:C535761 {'type': 'Disease', 'mesh': 'MESH:C535761'}
# MESH:C535762 {'type': 'Disease', 'mesh': 'MESH:C535762'}
# MESH:C535772 {'type': 'Disease', 'mesh': 'MESH:C535772'}
# MESH:C535773 {'type': 'Disease', 'mesh': 'MESH:C535773'}
# MESH:C535776 {'type': 'Disease', 'mesh': 'MESH:C535776'}
# MESH:C535780 {'type': 'Disease', 'mesh': 'MESH:C535780'}
# MESH:C535788 {'type': 'Disease', 'mesh': 'MESH:C535788'}
# MESH:C535800 {'type': 'Disease', 'mesh': 'MESH:C535800'}
# MESH:C535803 {'type': 'Disease', 'mesh': 'MESH:C535803'}
# MESH:C535804 {'type': 'Disease', 'mesh': 'MESH:C535804'}
# MESH:C535805 {'type': 'Disease', 'mesh': 'MESH:C535805'}
# MESH:C535808 {'type': 'Disease', 'mesh': 'MESH:C535808'}
# MESH:C535814 {'type': 'Disease', 'mesh': 'MESH:C535814'}
# MESH:C535815 {'type': 'Disease', 'mesh': 'MESH:C535815'}
# MESH:C535821 {'type': 'Disease', 'mesh': 'MESH:C535821'}
# MESH:C535827 {'type': 'Disease', 'mesh': 'MESH:C535827'}
# MESH:C535837 {'type': 'Disease', 'mesh': 'MESH:C535837'}
# MESH:C535841 {'type': 'Disease', 'mesh': 'MESH:C535841'}
# MESH:C535842 {'type': 'Disease', 'mesh': 'MESH:C535842'}
# MESH:C535854 {'type': 'Disease', 'mesh': 'MESH:C535854'}
# MESH:C535857 {'type': 'Disease', 'mesh': 'MESH:C535857'}
# MESH:C535880 {'type': 'Disease', 'mesh': 'MESH:C535880'}
# MESH:C535887 {'type': 'Disease', 'mesh': 'MESH:C535887'}
# MESH:C535895 {'type': 'Disease', 'mesh': 'MESH:C535895'}
# MESH:C535897 {'type': 'Disease', 'mesh': 'MESH:C535897'}
# MESH:C535903 {'type': 'Disease', 'mesh': 'MESH:C535903'}
# MESH:C535909 {'type': 'Disease', 'mesh': 'MESH:C535909'}
# MESH:C535911 {'type': 'Disease', 'mesh': 'MESH:C535911'}
# MESH:C535918 {'type': 'Disease', 'mesh': 'MESH:C535918'}
# MESH:C535919 {'type': 'Disease', 'mesh': 'MESH:C535919'}
# MESH:C535923 {'type': 'Disease', 'mesh': 'MESH:C535923'}
# MESH:C535924 {'type': 'Disease', 'mesh': 'MESH:C535924'}
# MESH:C535932 {'type': 'Disease', 'mesh': 'MESH:C535932'}
# MESH:C535933 {'type': 'Disease', 'mesh': 'MESH:C535933'}
# MESH:C535942 {'type': 'Disease', 'mesh': 'MESH:C535942'}
# MESH:C535952 {'type': 'Disease', 'mesh': 'MESH:C535952'}
# MESH:C535953 {'type': 'Disease', 'mesh': 'MESH:C535953'}
# MESH:C535955 {'type': 'Disease', 'mesh': 'MESH:C535955'}
# MESH:C535964 {'type': 'Disease', 'mesh': 'MESH:C535964'}
# MESH:C535970 {'type': 'Disease', 'mesh': 'MESH:C535970'}
# MESH:C535978 {'type': 'Disease', 'mesh': 'MESH:C535978'}
# MESH:C535979 {'type': 'Disease', 'mesh': 'MESH:C535979'}
# MESH:C535981 {'type': 'Disease', 'mesh': 'MESH:C535981'}
# MESH:C535982 {'type': 'Disease', 'mesh': 'MESH:C535982'}
# MESH:C535984 {'type': 'Disease', 'mesh': 'MESH:C535984'}
# MESH:C535990 {'type': 'Disease', 'mesh': 'MESH:C535990'}
# MESH:C536004 {'type': 'Disease', 'mesh': 'MESH:C536004'}
# MESH:C536008 {'type': 'Disease', 'mesh': 'MESH:C536008'}
# MESH:C536021 {'type': 'Disease', 'mesh': 'MESH:C536021'}
# MESH:C536025 {'type': 'Disease', 'mesh': 'MESH:C536025'}
# MESH:C536029 {'type': 'Disease', 'mesh': 'MESH:C536029'}
# MESH:C536030 {'type': 'Disease', 'mesh': 'MESH:C536030'}
# MESH:C536038 {'type': 'Disease', 'mesh': 'MESH:C536038'}
# MESH:C536049 {'type': 'Disease', 'mesh': 'MESH:C536049'}
# MESH:C536051 {'type': 'Disease', 'mesh': 'MESH:C536051'}
# MESH:C536059 {'type': 'Disease', 'mesh': 'MESH:C536059'}
# MESH:C536063 {'type': 'Disease', 'mesh': 'MESH:C536063'}
# MESH:C536068 {'type': 'Disease', 'mesh': 'MESH:C536068'}
# MESH:C536075 {'type': 'Disease', 'mesh': 'MESH:C536075'}
# MESH:C536078 {'type': 'Disease', 'mesh': 'MESH:C536078'}
# MESH:C536080 {'type': 'Disease', 'mesh': 'MESH:C536080'}
# MESH:C536096 {'type': 'Disease', 'mesh': 'MESH:C536096'}
# MESH:C536112 {'type': 'Disease', 'mesh': 'MESH:C536112'}
# MESH:C536122 {'type': 'Disease', 'mesh': 'MESH:C536122'}
# MESH:C536128 {'type': 'Disease', 'mesh': 'MESH:C536128'}
# MESH:C536129 {'type': 'Disease', 'mesh': 'MESH:C536129'}
# MESH:C536133 {'type': 'Disease', 'mesh': 'MESH:C536133'}
# MESH:C536136 {'type': 'Disease', 'mesh': 'MESH:C536136'}
# MESH:C536156 {'type': 'Disease', 'mesh': 'MESH:C536156'}
# MESH:C536164 {'type': 'Disease', 'mesh': 'MESH:C536164'}
# MESH:C536167 {'type': 'Disease', 'mesh': 'MESH:C536167'}
# MESH:C536168 {'type': 'Disease', 'mesh': 'MESH:C536168'}
# MESH:C536174 {'type': 'Disease', 'mesh': 'MESH:C536174'}
# MESH:C536176 {'type': 'Disease', 'mesh': 'MESH:C536176'}
# MESH:C536189 {'type': 'Disease', 'mesh': 'MESH:C536189'}
# MESH:C536192 {'type': 'Disease', 'mesh': 'MESH:C536192'}
# MESH:C536209 {'type': 'Disease', 'mesh': 'MESH:C536209'}
# MESH:C536210 {'type': 'Disease', 'mesh': 'MESH:C536210'}
# MESH:C536211 {'type': 'Disease', 'mesh': 'MESH:C536211'}
# MESH:C536221 {'type': 'Disease', 'mesh': 'MESH:C536221'}
# MESH:C536223 {'type': 'Disease', 'mesh': 'MESH:C536223'}
# MESH:C536227 {'type': 'Disease', 'mesh': 'MESH:C536227'}
# MESH:C536228 {'type': 'Disease', 'mesh': 'MESH:C536228'}
# MESH:C536231 {'type': 'Disease', 'mesh': 'MESH:C536231'}
# MESH:C536237 {'type': 'Disease', 'mesh': 'MESH:C536237'}
# MESH:C536254 {'type': 'Disease', 'mesh': 'MESH:C536254'}
# MESH:C536273 {'type': 'Disease', 'mesh': 'MESH:C536273'}
# MESH:C536282 {'type': 'Disease', 'mesh': 'MESH:C536282'}
# MESH:C536293 {'type': 'Disease', 'mesh': 'MESH:C536293'}
# MESH:C536294 {'type': 'Disease', 'mesh': 'MESH:C536294'}
# MESH:C536305 {'type': 'Disease', 'mesh': 'MESH:C536305'}
# MESH:C536311 {'type': 'Disease', 'mesh': 'MESH:C536311'}
# MESH:C536317 {'type': 'Disease', 'mesh': 'MESH:C536317'}
# MESH:C536321 {'type': 'Disease', 'mesh': 'MESH:C536321'}
# MESH:C536329 {'type': 'Disease', 'mesh': 'MESH:C536329'}
# MESH:C536330 {'type': 'Disease', 'mesh': 'MESH:C536330'}
# MESH:C536334 {'type': 'Disease', 'mesh': 'MESH:C536334'}
# MESH:C536335 {'type': 'Disease', 'mesh': 'MESH:C536335'}
# MESH:C536353 {'type': 'Disease', 'mesh': 'MESH:C536353'}
# MESH:C536357 {'type': 'Disease', 'mesh': 'MESH:C536357'}
# MESH:C536358 {'type': 'Disease', 'mesh': 'MESH:C536358'}
# MESH:C536376 {'type': 'Disease', 'mesh': 'MESH:C536376'}
# MESH:C536382 {'type': 'Disease', 'mesh': 'MESH:C536382'}
# MESH:C536385 {'type': 'Disease', 'mesh': 'MESH:C536385'}
# MESH:C536390 {'type': 'Disease', 'mesh': 'MESH:C536390'}
# MESH:C536397 {'type': 'Disease', 'mesh': 'MESH:C536397'}
# MESH:C536399 {'type': 'Disease', 'mesh': 'MESH:C536399'}
# MESH:C536404 {'type': 'Disease', 'mesh': 'MESH:C536404'}
# MESH:C536411 {'type': 'Disease', 'mesh': 'MESH:C536411'}
# MESH:C536416 {'type': 'Disease', 'mesh': 'MESH:C536416'}
# MESH:C536426 {'type': 'Disease', 'mesh': 'MESH:C536426'}
# MESH:C536436 {'type': 'Disease', 'mesh': 'MESH:C536436'}
# MESH:C536438 {'type': 'Disease', 'mesh': 'MESH:C536438'}
# MESH:C536439 {'type': 'Disease', 'mesh': 'MESH:C536439'}
# MESH:C536447 {'type': 'Disease', 'mesh': 'MESH:C536447'}
# MESH:C536453 {'type': 'Disease', 'mesh': 'MESH:C536453'}
# MESH:C536456 {'type': 'Disease', 'mesh': 'MESH:C536456'}
# MESH:C536457 {'type': 'Disease', 'mesh': 'MESH:C536457'}
# MESH:C536458 {'type': 'Disease', 'mesh': 'MESH:C536458'}
# MESH:C536463 {'type': 'Disease', 'mesh': 'MESH:C536463'}
# MESH:C536464 {'type': 'Disease', 'mesh': 'MESH:C536464'}
# MESH:C536467 {'type': 'Disease', 'mesh': 'MESH:C536467'}
# MESH:C536474 {'type': 'Disease', 'mesh': 'MESH:C536474'}
# MESH:C536480 {'type': 'Disease', 'mesh': 'MESH:C536480'}
# MESH:C536482 {'type': 'Disease', 'mesh': 'MESH:C536482'}
# MESH:C536492 {'type': 'Disease', 'mesh': 'MESH:C536492'}
# MESH:C536494 {'type': 'Disease', 'mesh': 'MESH:C536494'}
# MESH:C536495 {'type': 'Disease', 'mesh': 'MESH:C536495'}
# MESH:C536510 {'type': 'Disease', 'mesh': 'MESH:C536510'}
# MESH:C536512 {'type': 'Disease', 'mesh': 'MESH:C536512'}
# MESH:C536522 {'type': 'Disease', 'mesh': 'MESH:C536522'}
# MESH:C536525 {'type': 'Disease', 'mesh': 'MESH:C536525'}
# MESH:C536528 {'type': 'Disease', 'mesh': 'MESH:C536528'}
# MESH:C536531 {'type': 'Disease', 'mesh': 'MESH:C536531'}
# MESH:C536560 {'type': 'Disease', 'mesh': 'MESH:C536560'}
# MESH:C536561 {'type': 'Disease', 'mesh': 'MESH:C536561'}
# MESH:C536575 {'type': 'Disease', 'mesh': 'MESH:C536575'}
# MESH:C536591 {'type': 'Disease', 'mesh': 'MESH:C536591'}
# MESH:C536594 {'type': 'Disease', 'mesh': 'MESH:C536594'}
# MESH:C536601 {'type': 'Disease', 'mesh': 'MESH:C536601'}
# MESH:C536604 {'type': 'Disease', 'mesh': 'MESH:C536604'}
# MESH:C536607 {'type': 'Disease', 'mesh': 'MESH:C536607'}
# MESH:C536611 {'type': 'Disease', 'mesh': 'MESH:C536611'}
# MESH:C536624 {'type': 'Disease', 'mesh': 'MESH:C536624'}
# MESH:C536632 {'type': 'Disease', 'mesh': 'MESH:C536632'}
# MESH:C536641 {'type': 'Disease', 'mesh': 'MESH:C536641'}
# MESH:C536644 {'type': 'Disease', 'mesh': 'MESH:C536644'}
# MESH:C536648 {'type': 'Disease', 'mesh': 'MESH:C536648'}
# MESH:C536657 {'type': 'Disease', 'mesh': 'MESH:C536657'}
# MESH:C536662 {'type': 'Disease', 'mesh': 'MESH:C536662'}
# MESH:C536665 {'type': 'Disease', 'mesh': 'MESH:C536665'}
# MESH:C536677 {'type': 'Disease', 'mesh': 'MESH:C536677'}
# MESH:C536681 {'type': 'Disease', 'mesh': 'MESH:C536681'}
# MESH:C536687 {'type': 'Disease', 'mesh': 'MESH:C536687'}
# MESH:C536693 {'type': 'Disease', 'mesh': 'MESH:C536693'}
# MESH:C536695 {'type': 'Disease', 'mesh': 'MESH:C536695'}
# MESH:C536697 {'type': 'Disease', 'mesh': 'MESH:C536697'}
# MESH:C536709 {'type': 'Disease', 'mesh': 'MESH:C536709'}
# MESH:C536722 {'type': 'Disease', 'mesh': 'MESH:C536722'}
# MESH:C536729 {'type': 'Disease', 'mesh': 'MESH:C536729'}
# MESH:C536736 {'type': 'Disease', 'mesh': 'MESH:C536736'}
# MESH:C536739 {'type': 'Disease', 'mesh': 'MESH:C536739'}
# MESH:C536745 {'type': 'Disease', 'mesh': 'MESH:C536745'}
# MESH:C536750 {'type': 'Disease', 'mesh': 'MESH:C536750'}
# MESH:C536761 {'type': 'Disease', 'mesh': 'MESH:C536761'}
# MESH:C536762 {'type': 'Disease', 'mesh': 'MESH:C536762'}
# MESH:C536769 {'type': 'Disease', 'mesh': 'MESH:C536769'}
# MESH:C536772 {'type': 'Disease', 'mesh': 'MESH:C536772'}
# MESH:C536773 {'type': 'Disease', 'mesh': 'MESH:C536773'}
# MESH:C536777 {'type': 'Disease', 'mesh': 'MESH:C536777'}
# MESH:C536778 {'type': 'Disease', 'mesh': 'MESH:C536778'}
# MESH:C536783 {'type': 'Disease', 'mesh': 'MESH:C536783'}
# MESH:C536787 {'type': 'Disease', 'mesh': 'MESH:C536787'}
# MESH:C536788 {'type': 'Disease', 'mesh': 'MESH:C536788'}
# MESH:C536799 {'type': 'Disease', 'mesh': 'MESH:C536799'}
# MESH:C536801 {'type': 'Disease', 'mesh': 'MESH:C536801'}
# MESH:C536816 {'type': 'Disease', 'mesh': 'MESH:C536816'}
# MESH:C536820 {'type': 'Disease', 'mesh': 'MESH:C536820'}
# MESH:C536821 {'type': 'Disease', 'mesh': 'MESH:C536821'}
# MESH:C536830 {'type': 'Disease', 'mesh': 'MESH:C536830'}
# MESH:C536833 {'type': 'Disease', 'mesh': 'MESH:C536833'}
# MESH:C536841 {'type': 'Disease', 'mesh': 'MESH:C536841'}
# MESH:C536842 {'type': 'Disease', 'mesh': 'MESH:C536842'}
# MESH:C536850 {'type': 'Disease', 'mesh': 'MESH:C536850'}
# MESH:C536851 {'type': 'Disease', 'mesh': 'MESH:C536851'}
# MESH:C536858 {'type': 'Disease', 'mesh': 'MESH:C536858'}
# MESH:C536871 {'type': 'Disease', 'mesh': 'MESH:C536871'}
# MESH:C536875 {'type': 'Disease', 'mesh': 'MESH:C536875'}
# MESH:C536880 {'type': 'Disease', 'mesh': 'MESH:C536880'}
# MESH:C536905 {'type': 'Disease', 'mesh': 'MESH:C536905'}
# MESH:C536910 {'type': 'Disease', 'mesh': 'MESH:C536910'}
# MESH:C536911 {'type': 'Disease', 'mesh': 'MESH:C536911'}
# MESH:C536913 {'type': 'Disease', 'mesh': 'MESH:C536913'}
# MESH:C536914 {'type': 'Disease', 'mesh': 'MESH:C536914'}
# MESH:C536915 {'type': 'Disease', 'mesh': 'MESH:C536915'}
# MESH:C536917 {'type': 'Disease', 'mesh': 'MESH:C536917'}
# MESH:C536919 {'type': 'Disease', 'mesh': 'MESH:C536919'}
# MESH:C536924 {'type': 'Disease', 'mesh': 'MESH:C536924'}
# MESH:C536928 {'type': 'Disease', 'mesh': 'MESH:C536928'}
# MESH:C536937 {'type': 'Disease', 'mesh': 'MESH:C536937'}
# MESH:C536940 {'type': 'Disease', 'mesh': 'MESH:C536940'}
# MESH:C536946 {'type': 'Disease', 'mesh': 'MESH:C536946'}
# MESH:C536961 {'type': 'Disease', 'mesh': 'MESH:C536961'}
# MESH:C536962 {'type': 'Disease', 'mesh': 'MESH:C536962'}
# MESH:C536965 {'type': 'Disease', 'mesh': 'MESH:C536965'}
# MESH:C536973 {'type': 'Disease', 'mesh': 'MESH:C536973'}
# MESH:C536974 {'type': 'Disease', 'mesh': 'MESH:C536974'}
# MESH:C536984 {'type': 'Disease', 'mesh': 'MESH:C536984'}
# MESH:C536987 {'type': 'Disease', 'mesh': 'MESH:C536987'}
# MESH:C536990 {'type': 'Disease', 'mesh': 'MESH:C536990'}
# MESH:C537007 {'type': 'Disease', 'mesh': 'MESH:C537007'}
# MESH:C537013 {'type': 'Disease', 'mesh': 'MESH:C537013'}
# MESH:C537015 {'type': 'Disease', 'mesh': 'MESH:C537015'}
# MESH:C537030 {'type': 'Disease', 'mesh': 'MESH:C537030'}
# MESH:C537031 {'type': 'Disease', 'mesh': 'MESH:C537031'}
# MESH:C537034 {'type': 'Disease', 'mesh': 'MESH:C537034'}
# MESH:C537042 {'type': 'Disease', 'mesh': 'MESH:C537042'}
# MESH:C537045 {'type': 'Disease', 'mesh': 'MESH:C537045'}
# MESH:C537047 {'type': 'Disease', 'mesh': 'MESH:C537047'}
# MESH:C537048 {'type': 'Disease', 'mesh': 'MESH:C537048'}
# MESH:C537060 {'type': 'Disease', 'mesh': 'MESH:C537060'}
# MESH:C537062 {'type': 'Disease', 'mesh': 'MESH:C537062'}
# MESH:C537072 {'type': 'Disease', 'mesh': 'MESH:C537072'}
# MESH:C537081 {'type': 'Disease', 'mesh': 'MESH:C537081'}
# MESH:C537088 {'type': 'Disease', 'mesh': 'MESH:C537088'}
# MESH:C537089 {'type': 'Disease', 'mesh': 'MESH:C537089'}
# MESH:C537093 {'type': 'Disease', 'mesh': 'MESH:C537093'}
# MESH:C537097 {'type': 'Disease', 'mesh': 'MESH:C537097'}
# MESH:C537098 {'type': 'Disease', 'mesh': 'MESH:C537098'}
# MESH:C537104 {'type': 'Disease', 'mesh': 'MESH:C537104'}
# MESH:C537108 {'type': 'Disease', 'mesh': 'MESH:C537108'}
# MESH:C537111 {'type': 'Disease', 'mesh': 'MESH:C537111'}
# MESH:C537119 {'type': 'Disease', 'mesh': 'MESH:C537119'}
# MESH:C537125 {'type': 'Disease', 'mesh': 'MESH:C537125'}
# MESH:C537145 {'type': 'Disease', 'mesh': 'MESH:C537145'}
# MESH:C537152 {'type': 'Disease', 'mesh': 'MESH:C537152'}
# MESH:C537157 {'type': 'Disease', 'mesh': 'MESH:C537157'}
# MESH:C537160 {'type': 'Disease', 'mesh': 'MESH:C537160'}
# MESH:C537162 {'type': 'Disease', 'mesh': 'MESH:C537162'}
# MESH:C537168 {'type': 'Disease', 'mesh': 'MESH:C537168'}
# MESH:C537177 {'type': 'Disease', 'mesh': 'MESH:C537177'}
# MESH:C537180 {'type': 'Disease', 'mesh': 'MESH:C537180'}
# MESH:C537181 {'type': 'Disease', 'mesh': 'MESH:C537181'}
# MESH:C537182 {'type': 'Disease', 'mesh': 'MESH:C537182'}
# MESH:C537185 {'type': 'Disease', 'mesh': 'MESH:C537185'}
# MESH:C537189 {'type': 'Disease', 'mesh': 'MESH:C537189'}
# MESH:C537194 {'type': 'Disease', 'mesh': 'MESH:C537194'}
# MESH:C537195 {'type': 'Disease', 'mesh': 'MESH:C537195'}
# MESH:C537199 {'type': 'Disease', 'mesh': 'MESH:C537199'}
# MESH:C537202 {'type': 'Disease', 'mesh': 'MESH:C537202'}
# MESH:C537209 {'type': 'Disease', 'mesh': 'MESH:C537209'}
# MESH:C537221 {'type': 'Disease', 'mesh': 'MESH:C537221'}
# MESH:C537223 {'type': 'Disease', 'mesh': 'MESH:C537223'}
# MESH:C537224 {'type': 'Disease', 'mesh': 'MESH:C537224'}
# MESH:C537240 {'type': 'Disease', 'mesh': 'MESH:C537240'}
# MESH:C537242 {'type': 'Disease', 'mesh': 'MESH:C537242'}
# MESH:C537243 {'type': 'Disease', 'mesh': 'MESH:C537243'}
# MESH:C537247 {'type': 'Disease', 'mesh': 'MESH:C537247'}
# MESH:C537248 {'type': 'Disease', 'mesh': 'MESH:C537248'}
# MESH:C537249 {'type': 'Disease', 'mesh': 'MESH:C537249'}
# MESH:C537250 {'type': 'Disease', 'mesh': 'MESH:C537250'}
# MESH:C537251 {'type': 'Disease', 'mesh': 'MESH:C537251'}
# MESH:C537256 {'type': 'Disease', 'mesh': 'MESH:C537256'}
# MESH:C537262 {'type': 'Disease', 'mesh': 'MESH:C537262'}
# MESH:C537268 {'type': 'Disease', 'mesh': 'MESH:C537268'}
# MESH:C537274 {'type': 'Disease', 'mesh': 'MESH:C537274'}
# MESH:C537279 {'type': 'Disease', 'mesh': 'MESH:C537279'}
# MESH:C537286 {'type': 'Disease', 'mesh': 'MESH:C537286'}
# MESH:C537288 {'type': 'Disease', 'mesh': 'MESH:C537288'}
# MESH:C537296 {'type': 'Disease', 'mesh': 'MESH:C537296'}
# MESH:C537300 {'type': 'Disease', 'mesh': 'MESH:C537300'}
# MESH:C537308 {'type': 'Disease', 'mesh': 'MESH:C537308'}
# MESH:C537323 {'type': 'Disease', 'mesh': 'MESH:C537323'}
# MESH:C537330 {'type': 'Disease', 'mesh': 'MESH:C537330'}
# MESH:C537340 {'type': 'Disease', 'mesh': 'MESH:C537340'}
# MESH:C537345 {'type': 'Disease', 'mesh': 'MESH:C537345'}
# MESH:C537346 {'type': 'Disease', 'mesh': 'MESH:C537346'}
# MESH:C537358 {'type': 'Disease', 'mesh': 'MESH:C537358'}
# MESH:C537366 {'type': 'Disease', 'mesh': 'MESH:C537366'}
# MESH:C537369 {'type': 'Disease', 'mesh': 'MESH:C537369'}
# MESH:C537371 {'type': 'Disease', 'mesh': 'MESH:C537371'}
# MESH:C537372 {'type': 'Disease', 'mesh': 'MESH:C537372'}
# MESH:C537373 {'type': 'Disease', 'mesh': 'MESH:C537373'}
# MESH:C537374 {'type': 'Disease', 'mesh': 'MESH:C537374'}
# MESH:C537375 {'type': 'Disease', 'mesh': 'MESH:C537375'}
# MESH:C537377 {'type': 'Disease', 'mesh': 'MESH:C537377'}
# MESH:C537384 {'type': 'Disease', 'mesh': 'MESH:C537384'}
# MESH:C537387 {'type': 'Disease', 'mesh': 'MESH:C537387'}
# MESH:C537393 {'type': 'Disease', 'mesh': 'MESH:C537393'}
# MESH:C537396 {'type': 'Disease', 'mesh': 'MESH:C537396'}
# MESH:C537403 {'type': 'Disease', 'mesh': 'MESH:C537403'}
# MESH:C537407 {'type': 'Disease', 'mesh': 'MESH:C537407'}
# MESH:C537409 {'type': 'Disease', 'mesh': 'MESH:C537409'}
# MESH:C537412 {'type': 'Disease', 'mesh': 'MESH:C537412'}
# MESH:C537415 {'type': 'Disease', 'mesh': 'MESH:C537415'}
# MESH:C537419 {'type': 'Disease', 'mesh': 'MESH:C537419'}
# MESH:C537422 {'type': 'Disease', 'mesh': 'MESH:C537422'}
# MESH:C537426 {'type': 'Disease', 'mesh': 'MESH:C537426'}
# MESH:C537430 {'type': 'Disease', 'mesh': 'MESH:C537430'}
# MESH:C537436 {'type': 'Disease', 'mesh': 'MESH:C537436'}
# MESH:C537440 {'type': 'Disease', 'mesh': 'MESH:C537440'}
# MESH:C537443 {'type': 'Disease', 'mesh': 'MESH:C537443'}
# MESH:C537459 {'type': 'Disease', 'mesh': 'MESH:C537459'}
# MESH:C537465 {'type': 'Disease', 'mesh': 'MESH:C537465'}
# MESH:C537470 {'type': 'Disease', 'mesh': 'MESH:C537470'}
# MESH:C537475 {'type': 'Disease', 'mesh': 'MESH:C537475'}
# MESH:C537480 {'type': 'Disease', 'mesh': 'MESH:C537480'}
# MESH:C537482 {'type': 'Disease', 'mesh': 'MESH:C537482'}
# MESH:C537489 {'type': 'Disease', 'mesh': 'MESH:C537489'}
# MESH:C537492 {'type': 'Disease', 'mesh': 'MESH:C537492'}
# MESH:C537493 {'type': 'Disease', 'mesh': 'MESH:C537493'}
# MESH:C537494 {'type': 'Disease', 'mesh': 'MESH:C537494'}
# MESH:C537500 {'type': 'Disease', 'mesh': 'MESH:C537500'}
# MESH:C537501 {'type': 'Disease', 'mesh': 'MESH:C537501'}
# MESH:C537502 {'type': 'Disease', 'mesh': 'MESH:C537502'}
# MESH:C537503 {'type': 'Disease', 'mesh': 'MESH:C537503'}
# MESH:C537516 {'type': 'Disease', 'mesh': 'MESH:C537516'}
# MESH:C537521 {'type': 'Disease', 'mesh': 'MESH:C537521'}
# MESH:C537525 {'type': 'Disease', 'mesh': 'MESH:C537525'}
# MESH:C537527 {'type': 'Disease', 'mesh': 'MESH:C537527'}
# MESH:C537537 {'type': 'Disease', 'mesh': 'MESH:C537537'}
# MESH:C537559 {'type': 'Disease', 'mesh': 'MESH:C537559'}
# MESH:C537565 {'type': 'Disease', 'mesh': 'MESH:C537565'}
# MESH:C537580 {'type': 'Disease', 'mesh': 'MESH:C537580'}
# MESH:C537590 {'type': 'Disease', 'mesh': 'MESH:C537590'}
# MESH:C537592 {'type': 'Disease', 'mesh': 'MESH:C537592'}
# MESH:C537602 {'type': 'Disease', 'mesh': 'MESH:C537602'}
# MESH:C537617 {'type': 'Disease', 'mesh': 'MESH:C537617'}
# MESH:C537620 {'type': 'Disease', 'mesh': 'MESH:C537620'}
# MESH:C537622 {'type': 'Disease', 'mesh': 'MESH:C537622'}
# MESH:C537630 {'type': 'Disease', 'mesh': 'MESH:C537630'}
# MESH:C537633 {'type': 'Disease', 'mesh': 'MESH:C537633'}
# MESH:C537653 {'type': 'Disease', 'mesh': 'MESH:C537653'}
# MESH:C537656 {'type': 'Disease', 'mesh': 'MESH:C537656'}
# MESH:C537680 {'type': 'Disease', 'mesh': 'MESH:C537680'}
# MESH:C537696 {'type': 'Disease', 'mesh': 'MESH:C537696'}
# MESH:C537699 {'type': 'Disease', 'mesh': 'MESH:C537699'}
# MESH:C537702 {'type': 'Disease', 'mesh': 'MESH:C537702'}
# MESH:C537705 {'type': 'Disease', 'mesh': 'MESH:C537705'}
# MESH:C537710 {'type': 'Disease', 'mesh': 'MESH:C537710'}
# MESH:C537717 {'type': 'Disease', 'mesh': 'MESH:C537717'}
# MESH:C537723 {'type': 'Disease', 'mesh': 'MESH:C537723'}
# MESH:C537727 {'type': 'Disease', 'mesh': 'MESH:C537727'}
# MESH:C537728 {'type': 'Disease', 'mesh': 'MESH:C537728'}
# MESH:C537730 {'type': 'Disease', 'mesh': 'MESH:C537730'}
# MESH:C537731 {'type': 'Disease', 'mesh': 'MESH:C537731'}
# MESH:C537734 {'type': 'Disease', 'mesh': 'MESH:C537734'}
# MESH:C537743 {'type': 'Disease', 'mesh': 'MESH:C537743'}
# MESH:C537750 {'type': 'Disease', 'mesh': 'MESH:C537750'}
# MESH:C537757 {'type': 'Disease', 'mesh': 'MESH:C537757'}
# MESH:C537768 {'type': 'Disease', 'mesh': 'MESH:C537768'}
# MESH:C537771 {'type': 'Disease', 'mesh': 'MESH:C537771'}
# MESH:C537775 {'type': 'Disease', 'mesh': 'MESH:C537775'}
# MESH:C537778 {'type': 'Disease', 'mesh': 'MESH:C537778'}
# MESH:C537799 {'type': 'Disease', 'mesh': 'MESH:C537799'}
# MESH:C537814 {'type': 'Disease', 'mesh': 'MESH:C537814'}
# MESH:C537829 {'type': 'Disease', 'mesh': 'MESH:C537829'}
# MESH:C537834 {'type': 'Disease', 'mesh': 'MESH:C537834'}
# MESH:C537835 {'type': 'Disease', 'mesh': 'MESH:C537835'}
# MESH:C537839 {'type': 'Disease', 'mesh': 'MESH:C537839'}
# MESH:C537844 {'type': 'Disease', 'mesh': 'MESH:C537844'}
# MESH:C537845 {'type': 'Disease', 'mesh': 'MESH:C537845'}
# MESH:C537846 {'type': 'Disease', 'mesh': 'MESH:C537846'}
# MESH:C537849 {'type': 'Disease', 'mesh': 'MESH:C537849'}
# MESH:C537860 {'type': 'Disease', 'mesh': 'MESH:C537860'}
# MESH:C537863 {'type': 'Disease', 'mesh': 'MESH:C537863'}
# MESH:C537875 {'type': 'Disease', 'mesh': 'MESH:C537875'}
# MESH:C537876 {'type': 'Disease', 'mesh': 'MESH:C537876'}
# MESH:C537881 {'type': 'Disease', 'mesh': 'MESH:C537881'}
# MESH:C537884 {'type': 'Disease', 'mesh': 'MESH:C537884'}
# MESH:C537901 {'type': 'Disease', 'mesh': 'MESH:C537901'}
# MESH:C537904 {'type': 'Disease', 'mesh': 'MESH:C537904'}
# MESH:C537907 {'type': 'Disease', 'mesh': 'MESH:C537907'}
# MESH:C537912 {'type': 'Disease', 'mesh': 'MESH:C537912'}
# MESH:C537923 {'type': 'Disease', 'mesh': 'MESH:C537923'}
# MESH:C537931 {'type': 'Disease', 'mesh': 'MESH:C537931'}
# MESH:C537934 {'type': 'Disease', 'mesh': 'MESH:C537934'}
# MESH:C537942 {'type': 'Disease', 'mesh': 'MESH:C537942'}
# MESH:C537943 {'type': 'Disease', 'mesh': 'MESH:C537943'}
# MESH:C537947 {'type': 'Disease', 'mesh': 'MESH:C537947'}
# MESH:C537955 {'type': 'Disease', 'mesh': 'MESH:C537955'}
# MESH:C537957 {'type': 'Disease', 'mesh': 'MESH:C537957'}
# MESH:C537961 {'type': 'Disease', 'mesh': 'MESH:C537961'}
# MESH:C537993 {'type': 'Disease', 'mesh': 'MESH:C537993'}
# MESH:C537995 {'type': 'Disease', 'mesh': 'MESH:C537995'}
# MESH:C538001 {'type': 'Disease', 'mesh': 'MESH:C538001'}
# MESH:C538005 {'type': 'Disease', 'mesh': 'MESH:C538005'}
# MESH:C538011 {'type': 'Disease', 'mesh': 'MESH:C538011'}
# MESH:C538012 {'type': 'Disease', 'mesh': 'MESH:C538012'}
# MESH:C538020 {'type': 'Disease', 'mesh': 'MESH:C538020'}
# MESH:C538028 {'type': 'Disease', 'mesh': 'MESH:C538028'}
# MESH:C538037 {'type': 'Disease', 'mesh': 'MESH:C538037'}
# MESH:C538041 {'type': 'Disease', 'mesh': 'MESH:C538041'}
# MESH:C538042 {'type': 'Disease', 'mesh': 'MESH:C538042'}
# MESH:C538044 {'type': 'Disease', 'mesh': 'MESH:C538044'}
# MESH:C538046 {'type': 'Disease', 'mesh': 'MESH:C538046'}
# MESH:C538052 {'type': 'Disease', 'mesh': 'MESH:C538052'}
# MESH:C538053 {'type': 'Disease', 'mesh': 'MESH:C538053'}
# MESH:C538068 {'type': 'Disease', 'mesh': 'MESH:C538068'}
# MESH:C538080 {'type': 'Disease', 'mesh': 'MESH:C538080'}
# MESH:C538081 {'type': 'Disease', 'mesh': 'MESH:C538081'}
# MESH:C538090 {'type': 'Disease', 'mesh': 'MESH:C538090'}
# MESH:C538104 {'type': 'Disease', 'mesh': 'MESH:C538104'}
# MESH:C538109 {'type': 'Disease', 'mesh': 'MESH:C538109'}
# MESH:C538110 {'type': 'Disease', 'mesh': 'MESH:C538110'}
# MESH:C538118 {'type': 'Disease', 'mesh': 'MESH:C538118'}
# MESH:C538137 {'type': 'Disease', 'mesh': 'MESH:C538137'}
# MESH:C538138 {'type': 'Disease', 'mesh': 'MESH:C538138'}
# MESH:C538145 {'type': 'Disease', 'mesh': 'MESH:C538145'}
# MESH:C538153 {'type': 'Disease', 'mesh': 'MESH:C538153'}
# MESH:C538157 {'type': 'Disease', 'mesh': 'MESH:C538157'}
# MESH:C538159 {'type': 'Disease', 'mesh': 'MESH:C538159'}
# MESH:C538178 {'type': 'Disease', 'mesh': 'MESH:C538178'}
# MESH:C538179 {'type': 'Disease', 'mesh': 'MESH:C538179'}
# MESH:C538184 {'type': 'Disease', 'mesh': 'MESH:C538184'}
# MESH:C538189 {'type': 'Disease', 'mesh': 'MESH:C538189'}
# MESH:C538191 {'type': 'Disease', 'mesh': 'MESH:C538191'}
# MESH:C538194 {'type': 'Disease', 'mesh': 'MESH:C538194'}
# MESH:C538208 {'type': 'Disease', 'mesh': 'MESH:C538208'}
# MESH:C538212 {'type': 'Disease', 'mesh': 'MESH:C538212'}
# MESH:C538219 {'type': 'Disease', 'mesh': 'MESH:C538219'}
# MESH:C538223 {'type': 'Disease', 'mesh': 'MESH:C538223'}
# MESH:C538228 {'type': 'Disease', 'mesh': 'MESH:C538228'}
# MESH:C538229 {'type': 'Disease', 'mesh': 'MESH:C538229'}
# MESH:C538231 {'type': 'Disease', 'mesh': 'MESH:C538231'}
# MESH:C538235 {'type': 'Disease', 'mesh': 'MESH:C538235'}
# MESH:C538238 {'type': 'Disease', 'mesh': 'MESH:C538238'}
# MESH:C538241 {'type': 'Disease', 'mesh': 'MESH:C538241'}
# MESH:C538247 {'type': 'Disease', 'mesh': 'MESH:C538247'}
# MESH:C538248 {'type': 'Disease', 'mesh': 'MESH:C538248'}
# MESH:C538250 {'type': 'Disease', 'mesh': 'MESH:C538250'}
# MESH:C538253 {'type': 'Disease', 'mesh': 'MESH:C538253'}
# MESH:C538258 {'type': 'Disease', 'mesh': 'MESH:C538258'}
# MESH:C538261 {'type': 'Disease', 'mesh': 'MESH:C538261'}
# MESH:C538266 {'type': 'Disease', 'mesh': 'MESH:C538266'}
# MESH:C538268 {'type': 'Disease', 'mesh': 'MESH:C538268'}
# MESH:C538273 {'type': 'Disease', 'mesh': 'MESH:C538273'}
# MESH:C538274 {'type': 'Disease', 'mesh': 'MESH:C538274'}
# MESH:C538282 {'type': 'Disease', 'mesh': 'MESH:C538282'}
# MESH:C538284 {'type': 'Disease', 'mesh': 'MESH:C538284'}
# MESH:C538287 {'type': 'Disease', 'mesh': 'MESH:C538287'}
# MESH:C538308 {'type': 'Disease', 'mesh': 'MESH:C538308'}
# MESH:C538320 {'type': 'Disease', 'mesh': 'MESH:C538320'}
# MESH:C538336 {'type': 'Disease', 'mesh': 'MESH:C538336'}
# MESH:C538339 {'type': 'Disease', 'mesh': 'MESH:C538339'}
# MESH:C538343 {'type': 'Disease', 'mesh': 'MESH:C538343'}
# MESH:C538346 {'type': 'Disease', 'mesh': 'MESH:C538346'}
# MESH:C538355 {'type': 'Disease', 'mesh': 'MESH:C538355'}
# MESH:C538361 {'type': 'Disease', 'mesh': 'MESH:C538361'}
# MESH:C538362 {'type': 'Disease', 'mesh': 'MESH:C538362'}
# MESH:C538363 {'type': 'Disease', 'mesh': 'MESH:C538363'}
# MESH:C538365 {'type': 'Disease', 'mesh': 'MESH:C538365'}
# MESH:C538375 {'type': 'Disease', 'mesh': 'MESH:C538375'}
# MESH:C538380 {'type': 'Disease', 'mesh': 'MESH:C538380'}
# MESH:C538381 {'type': 'Disease', 'mesh': 'MESH:C538381'}
# MESH:C538384 {'type': 'Disease', 'mesh': 'MESH:C538384'}
# MESH:C538394 {'type': 'Disease', 'mesh': 'MESH:C538394'}
# MESH:C538400 {'type': 'Disease', 'mesh': 'MESH:C538400'}
# MESH:C538445 {'type': 'Disease', 'mesh': 'MESH:C538445'}
# MESH:C538457 {'type': 'Disease', 'mesh': 'MESH:C538457'}
# MESH:C538475 {'type': 'Disease', 'mesh': 'MESH:C538475'}
# MESH:C538481 {'type': 'Disease', 'mesh': 'MESH:C538481'}
# MESH:C538494 {'type': 'Disease', 'mesh': 'MESH:C538494'}
# MESH:C538507 {'type': 'Disease', 'mesh': 'MESH:C538507'}
# MESH:C538525 {'type': 'Disease', 'mesh': 'MESH:C538525'}
# MESH:C538613 {'type': 'Disease', 'mesh': 'MESH:C538613'}
# MESH:C538670 {'type': 'Disease', 'mesh': 'MESH:C538670'}
# MESH:C540770 {'type': 'Disease', 'mesh': 'MESH:C540770'}
# MESH:C541083 {'type': 'Disease', 'mesh': 'MESH:C541083'}
# MESH:C548032 {'type': 'Disease', 'mesh': 'MESH:C548032'}
# MESH:C548033 {'type': 'Disease', 'mesh': 'MESH:C548033'}
# MESH:C548069 {'type': 'Disease', 'mesh': 'MESH:C548069'}
# MESH:C548072 {'type': 'Disease', 'mesh': 'MESH:C548072'}
# MESH:C548075 {'type': 'Disease', 'mesh': 'MESH:C548075'}
# MESH:C548077 {'type': 'Disease', 'mesh': 'MESH:C548077'}
# MESH:C548080 {'type': 'Disease', 'mesh': 'MESH:C548080'}
# MESH:C548666 {'type': 'Disease', 'mesh': 'MESH:C548666'}
# MESH:C557674 {'type': 'Disease', 'mesh': 'MESH:C557674'}
# MESH:C562385 {'type': 'Disease', 'mesh': 'MESH:C562385'}
# MESH:C562386 {'type': 'Disease', 'mesh': 'MESH:C562386'}
# MESH:C562388 {'type': 'Disease', 'mesh': 'MESH:C562388'}
# MESH:C562390 {'type': 'Disease', 'mesh': 'MESH:C562390'}
# MESH:C562393 {'type': 'Disease', 'mesh': 'MESH:C562393'}
# MESH:C562396 {'type': 'Disease', 'mesh': 'MESH:C562396'}
# MESH:C562398 {'type': 'Disease', 'mesh': 'MESH:C562398'}
# MESH:C562399 {'type': 'Disease', 'mesh': 'MESH:C562399'}
# MESH:C562405 {'type': 'Disease', 'mesh': 'MESH:C562405'}
# MESH:C562406 {'type': 'Disease', 'mesh': 'MESH:C562406'}
# MESH:C562419 {'type': 'Disease', 'mesh': 'MESH:C562419'}
# MESH:C562429 {'type': 'Disease', 'mesh': 'MESH:C562429'}
# MESH:C562441 {'type': 'Disease', 'mesh': 'MESH:C562441'}
# MESH:C562460 {'type': 'Disease', 'mesh': 'MESH:C562460'}
# MESH:C562463 {'type': 'Disease', 'mesh': 'MESH:C562463'}
# MESH:C562465 {'type': 'Disease', 'mesh': 'MESH:C562465'}
# MESH:C562472 {'type': 'Disease', 'mesh': 'MESH:C562472'}
# MESH:C562477 {'type': 'Disease', 'mesh': 'MESH:C562477'}
# MESH:C562479 {'type': 'Disease', 'mesh': 'MESH:C562479'}
# MESH:C562485 {'type': 'Disease', 'mesh': 'MESH:C562485'}
# MESH:C562487 {'type': 'Disease', 'mesh': 'MESH:C562487'}
# MESH:C562489 {'type': 'Disease', 'mesh': 'MESH:C562489'}
# MESH:C562490 {'type': 'Disease', 'mesh': 'MESH:C562490'}
# MESH:C562503 {'type': 'Disease', 'mesh': 'MESH:C562503'}
# MESH:C562509 {'type': 'Disease', 'mesh': 'MESH:C562509'}
# MESH:C562515 {'type': 'Disease', 'mesh': 'MESH:C562515'}
# MESH:C562524 {'type': 'Disease', 'mesh': 'MESH:C562524'}
# MESH:C562546 {'type': 'Disease', 'mesh': 'MESH:C562546'}
# MESH:C562577 {'type': 'Disease', 'mesh': 'MESH:C562577'}
# MESH:C562594 {'type': 'Disease', 'mesh': 'MESH:C562594'}
# MESH:C562602 {'type': 'Disease', 'mesh': 'MESH:C562602'}
# MESH:C562618 {'type': 'Disease', 'mesh': 'MESH:C562618'}
# MESH:C562642 {'type': 'Disease', 'mesh': 'MESH:C562642'}
# MESH:C562662 {'type': 'Disease', 'mesh': 'MESH:C562662'}
# MESH:C562681 {'type': 'Disease', 'mesh': 'MESH:C562681'}
# MESH:C562687 {'type': 'Disease', 'mesh': 'MESH:C562687'}
# MESH:C562709 {'type': 'Disease', 'mesh': 'MESH:C562709'}
# MESH:C562719 {'type': 'Disease', 'mesh': 'MESH:C562719'}
# MESH:C562729 {'type': 'Disease', 'mesh': 'MESH:C562729'}
# MESH:C562731 {'type': 'Disease', 'mesh': 'MESH:C562731'}
# MESH:C562732 {'type': 'Disease', 'mesh': 'MESH:C562732'}
# MESH:C562733 {'type': 'Disease', 'mesh': 'MESH:C562733'}
# MESH:C562737 {'type': 'Disease', 'mesh': 'MESH:C562737'}
# MESH:C562740 {'type': 'Disease', 'mesh': 'MESH:C562740'}
# MESH:C562745 {'type': 'Disease', 'mesh': 'MESH:C562745'}
# MESH:C562750 {'type': 'Disease', 'mesh': 'MESH:C562750'}
# MESH:C562768 {'type': 'Disease', 'mesh': 'MESH:C562768'}
# MESH:C562772 {'type': 'Disease', 'mesh': 'MESH:C562772'}
# MESH:C562783 {'type': 'Disease', 'mesh': 'MESH:C562783'}
# MESH:C562785 {'type': 'Disease', 'mesh': 'MESH:C562785'}
# MESH:C562787 {'type': 'Disease', 'mesh': 'MESH:C562787'}
# MESH:C562791 {'type': 'Disease', 'mesh': 'MESH:C562791'}
# MESH:C562803 {'type': 'Disease', 'mesh': 'MESH:C562803'}
# MESH:C562827 {'type': 'Disease', 'mesh': 'MESH:C562827'}
# MESH:C562829 {'type': 'Disease', 'mesh': 'MESH:C562829'}
# MESH:C562831 {'type': 'Disease', 'mesh': 'MESH:C562831'}
# MESH:C562834 {'type': 'Disease', 'mesh': 'MESH:C562834'}
# MESH:C562839 {'type': 'Disease', 'mesh': 'MESH:C562839'}
# MESH:C562840 {'type': 'Disease', 'mesh': 'MESH:C562840'}
# MESH:C562868 {'type': 'Disease', 'mesh': 'MESH:C562868'}
# MESH:C562875 {'type': 'Disease', 'mesh': 'MESH:C562875'}
# MESH:C562884 {'type': 'Disease', 'mesh': 'MESH:C562884'}
# MESH:C562924 {'type': 'Disease', 'mesh': 'MESH:C562924'}
# MESH:C562935 {'type': 'Disease', 'mesh': 'MESH:C562935'}
# MESH:C562938 {'type': 'Disease', 'mesh': 'MESH:C562938'}
# MESH:C562942 {'type': 'Disease', 'mesh': 'MESH:C562942'}
# MESH:C562943 {'type': 'Disease', 'mesh': 'MESH:C562943'}
# MESH:C562951 {'type': 'Disease', 'mesh': 'MESH:C562951'}
# MESH:C562966 {'type': 'Disease', 'mesh': 'MESH:C562966'}
# MESH:C562978 {'type': 'Disease', 'mesh': 'MESH:C562978'}
# MESH:C562999 {'type': 'Disease', 'mesh': 'MESH:C562999'}
# MESH:C563007 {'type': 'Disease', 'mesh': 'MESH:C563007'}
# MESH:C563010 {'type': 'Disease', 'mesh': 'MESH:C563010'}
# MESH:C563016 {'type': 'Disease', 'mesh': 'MESH:C563016'}
# MESH:C563020 {'type': 'Disease', 'mesh': 'MESH:C563020'}
# MESH:C563037 {'type': 'Disease', 'mesh': 'MESH:C563037'}
# MESH:C563039 {'type': 'Disease', 'mesh': 'MESH:C563039'}
# MESH:C563043 {'type': 'Disease', 'mesh': 'MESH:C563043'}
# MESH:C563120 {'type': 'Disease', 'mesh': 'MESH:C563120'}
# MESH:C563160 {'type': 'Disease', 'mesh': 'MESH:C563160'}
# MESH:C563161 {'type': 'Disease', 'mesh': 'MESH:C563161'}
# MESH:C563162 {'type': 'Disease', 'mesh': 'MESH:C563162'}
# MESH:C563168 {'type': 'Disease', 'mesh': 'MESH:C563168'}
# MESH:C563178 {'type': 'Disease', 'mesh': 'MESH:C563178'}
# MESH:C563181 {'type': 'Disease', 'mesh': 'MESH:C563181'}
# MESH:C563184 {'type': 'Disease', 'mesh': 'MESH:C563184'}
# MESH:C563187 {'type': 'Disease', 'mesh': 'MESH:C563187'}
# MESH:C563192 {'type': 'Disease', 'mesh': 'MESH:C563192'}
# MESH:C563195 {'type': 'Disease', 'mesh': 'MESH:C563195'}
# MESH:C563207 {'type': 'Disease', 'mesh': 'MESH:C563207'}
# MESH:C563215 {'type': 'Disease', 'mesh': 'MESH:C563215'}
# MESH:C563236 {'type': 'Disease', 'mesh': 'MESH:C563236'}
# MESH:C563240 {'type': 'Disease', 'mesh': 'MESH:C563240'}
# MESH:C563256 {'type': 'Disease', 'mesh': 'MESH:C563256'}
# MESH:C563273 {'type': 'Disease', 'mesh': 'MESH:C563273'}
# MESH:C563276 {'type': 'Disease', 'mesh': 'MESH:C563276'}
# MESH:C563277 {'type': 'Disease', 'mesh': 'MESH:C563277'}
# MESH:C563375 {'type': 'Disease', 'mesh': 'MESH:C563375'}
# MESH:C563405 {'type': 'Disease', 'mesh': 'MESH:C563405'}
# MESH:C563409 {'type': 'Disease', 'mesh': 'MESH:C563409'}
# MESH:C563426 {'type': 'Disease', 'mesh': 'MESH:C563426'}
# MESH:C563466 {'type': 'Disease', 'mesh': 'MESH:C563466'}
# MESH:C563475 {'type': 'Disease', 'mesh': 'MESH:C563475'}
# MESH:C563477 {'type': 'Disease', 'mesh': 'MESH:C563477'}
# MESH:C563515 {'type': 'Disease', 'mesh': 'MESH:C563515'}
# MESH:C563523 {'type': 'Disease', 'mesh': 'MESH:C563523'}
# MESH:C563524 {'type': 'Disease', 'mesh': 'MESH:C563524'}
# MESH:C563541 {'type': 'Disease', 'mesh': 'MESH:C563541'}
# MESH:C563544 {'type': 'Disease', 'mesh': 'MESH:C563544'}
# MESH:C563551 {'type': 'Disease', 'mesh': 'MESH:C563551'}
# MESH:C563602 {'type': 'Disease', 'mesh': 'MESH:C563602'}
# MESH:C563673 {'type': 'Disease', 'mesh': 'MESH:C563673'}
# MESH:C563704 {'type': 'Disease', 'mesh': 'MESH:C563704'}
# MESH:C563775 {'type': 'Disease', 'mesh': 'MESH:C563775'}
# MESH:C563796 {'type': 'Disease', 'mesh': 'MESH:C563796'}
# MESH:C563799 {'type': 'Disease', 'mesh': 'MESH:C563799'}
# MESH:C563867 {'type': 'Disease', 'mesh': 'MESH:C563867'}
# MESH:C563895 {'type': 'Disease', 'mesh': 'MESH:C563895'}
# MESH:C563907 {'type': 'Disease', 'mesh': 'MESH:C563907'}
# MESH:C563914 {'type': 'Disease', 'mesh': 'MESH:C563914'}
# MESH:C563922 {'type': 'Disease', 'mesh': 'MESH:C563922'}
# MESH:C563984 {'type': 'Disease', 'mesh': 'MESH:C563984'}
# MESH:C563985 {'type': 'Disease', 'mesh': 'MESH:C563985'}
# MESH:C564048 {'type': 'Disease', 'mesh': 'MESH:C564048'}
# MESH:C564052 {'type': 'Disease', 'mesh': 'MESH:C564052'}
# MESH:C564053 {'type': 'Disease', 'mesh': 'MESH:C564053'}
# MESH:C564091 {'type': 'Disease', 'mesh': 'MESH:C564091'}
# MESH:C564105 {'type': 'Disease', 'mesh': 'MESH:C564105'}
# MESH:C564108 {'type': 'Disease', 'mesh': 'MESH:C564108'}
# MESH:C564133 {'type': 'Disease', 'mesh': 'MESH:C564133'}
# MESH:C564166 {'type': 'Disease', 'mesh': 'MESH:C564166'}
# MESH:C564181 {'type': 'Disease', 'mesh': 'MESH:C564181'}
# MESH:C564221 {'type': 'Disease', 'mesh': 'MESH:C564221'}
# MESH:C564245 {'type': 'Disease', 'mesh': 'MESH:C564245'}
# MESH:C564253 {'type': 'Disease', 'mesh': 'MESH:C564253'}
# MESH:C564254 {'type': 'Disease', 'mesh': 'MESH:C564254'}
# MESH:C564321 {'type': 'Disease', 'mesh': 'MESH:C564321'}
# MESH:C564323 {'type': 'Disease', 'mesh': 'MESH:C564323'}
# MESH:C564336 {'type': 'Disease', 'mesh': 'MESH:C564336'}
# MESH:C564342 {'type': 'Disease', 'mesh': 'MESH:C564342'}
# MESH:C564352 {'type': 'Disease', 'mesh': 'MESH:C564352'}
# MESH:C564372 {'type': 'Disease', 'mesh': 'MESH:C564372'}
# MESH:C564403 {'type': 'Disease', 'mesh': 'MESH:C564403'}
# MESH:C564469 {'type': 'Disease', 'mesh': 'MESH:C564469'}
# MESH:C564484 {'type': 'Disease', 'mesh': 'MESH:C564484'}
# MESH:C564487 {'type': 'Disease', 'mesh': 'MESH:C564487'}
# MESH:C564520 {'type': 'Disease', 'mesh': 'MESH:C564520'}
# MESH:C564539 {'type': 'Disease', 'mesh': 'MESH:C564539'}
# MESH:C564543 {'type': 'Disease', 'mesh': 'MESH:C564543'}
# MESH:C564591 {'type': 'Disease', 'mesh': 'MESH:C564591'}
# MESH:C564595 {'type': 'Disease', 'mesh': 'MESH:C564595'}
# MESH:C564603 {'type': 'Disease', 'mesh': 'MESH:C564603'}
# MESH:C564609 {'type': 'Disease', 'mesh': 'MESH:C564609'}
# MESH:C564616 {'type': 'Disease', 'mesh': 'MESH:C564616'}
# MESH:C564650 {'type': 'Disease', 'mesh': 'MESH:C564650'}
# MESH:C564683 {'type': 'Disease', 'mesh': 'MESH:C564683'}
# MESH:C564685 {'type': 'Disease', 'mesh': 'MESH:C564685'}
# MESH:C564694 {'type': 'Disease', 'mesh': 'MESH:C564694'}
# MESH:C564708 {'type': 'Disease', 'mesh': 'MESH:C564708'}
# MESH:C564735 {'type': 'Disease', 'mesh': 'MESH:C564735'}
# MESH:C564747 {'type': 'Disease', 'mesh': 'MESH:C564747'}
# MESH:C564777 {'type': 'Disease', 'mesh': 'MESH:C564777'}
# MESH:C564815 {'type': 'Disease', 'mesh': 'MESH:C564815'}
# MESH:C564816 {'type': 'Disease', 'mesh': 'MESH:C564816'}
# MESH:C564835 {'type': 'Disease', 'mesh': 'MESH:C564835'}
# MESH:C564858 {'type': 'Disease', 'mesh': 'MESH:C564858'}
# MESH:C564861 {'type': 'Disease', 'mesh': 'MESH:C564861'}
# MESH:C564871 {'type': 'Disease', 'mesh': 'MESH:C564871'}
# MESH:C564945 {'type': 'Disease', 'mesh': 'MESH:C564945'}
# MESH:C564955 {'type': 'Disease', 'mesh': 'MESH:C564955'}
# MESH:C564969 {'type': 'Disease', 'mesh': 'MESH:C564969'}
# MESH:C564992 {'type': 'Disease', 'mesh': 'MESH:C564992'}
# MESH:C565027 {'type': 'Disease', 'mesh': 'MESH:C565027'}
# MESH:C565079 {'type': 'Disease', 'mesh': 'MESH:C565079'}
# MESH:C565095 {'type': 'Disease', 'mesh': 'MESH:C565095'}
# MESH:C565128 {'type': 'Disease', 'mesh': 'MESH:C565128'}
# MESH:C565133 {'type': 'Disease', 'mesh': 'MESH:C565133'}
# MESH:C565137 {'type': 'Disease', 'mesh': 'MESH:C565137'}
# MESH:C565143 {'type': 'Disease', 'mesh': 'MESH:C565143'}
# MESH:C565153 {'type': 'Disease', 'mesh': 'MESH:C565153'}
# MESH:C565155 {'type': 'Disease', 'mesh': 'MESH:C565155'}
# MESH:C565165 {'type': 'Disease', 'mesh': 'MESH:C565165'}
# MESH:C565192 {'type': 'Disease', 'mesh': 'MESH:C565192'}
# MESH:C565193 {'type': 'Disease', 'mesh': 'MESH:C565193'}
# MESH:C565201 {'type': 'Disease', 'mesh': 'MESH:C565201'}
# MESH:C565209 {'type': 'Disease', 'mesh': 'MESH:C565209'}
# MESH:C565225 {'type': 'Disease', 'mesh': 'MESH:C565225'}
# MESH:C565232 {'type': 'Disease', 'mesh': 'MESH:C565232'}
# MESH:C565255 {'type': 'Disease', 'mesh': 'MESH:C565255'}
# MESH:C565309 {'type': 'Disease', 'mesh': 'MESH:C565309'}
# MESH:C565336 {'type': 'Disease', 'mesh': 'MESH:C565336'}
# MESH:C565343 {'type': 'Disease', 'mesh': 'MESH:C565343'}
# MESH:C565346 {'type': 'Disease', 'mesh': 'MESH:C565346'}
# MESH:C565436 {'type': 'Disease', 'mesh': 'MESH:C565436'}
# MESH:C565611 {'type': 'Disease', 'mesh': 'MESH:C565611'}
# MESH:C565662 {'type': 'Disease', 'mesh': 'MESH:C565662'}
# MESH:C565699 {'type': 'Disease', 'mesh': 'MESH:C565699'}
# MESH:C565732 {'type': 'Disease', 'mesh': 'MESH:C565732'}
# MESH:C565733 {'type': 'Disease', 'mesh': 'MESH:C565733'}
# MESH:C565753 {'type': 'Disease', 'mesh': 'MESH:C565753'}
# MESH:C565759 {'type': 'Disease', 'mesh': 'MESH:C565759'}
# MESH:C565772 {'type': 'Disease', 'mesh': 'MESH:C565772'}
# MESH:C565780 {'type': 'Disease', 'mesh': 'MESH:C565780'}
# MESH:C565789 {'type': 'Disease', 'mesh': 'MESH:C565789'}
# MESH:C565791 {'type': 'Disease', 'mesh': 'MESH:C565791'}
# MESH:C565798 {'type': 'Disease', 'mesh': 'MESH:C565798'}
# MESH:C565803 {'type': 'Disease', 'mesh': 'MESH:C565803'}
# MESH:C565815 {'type': 'Disease', 'mesh': 'MESH:C565815'}
# MESH:C565820 {'type': 'Disease', 'mesh': 'MESH:C565820'}
# MESH:C565827 {'type': 'Disease', 'mesh': 'MESH:C565827'}
# MESH:C565840 {'type': 'Disease', 'mesh': 'MESH:C565840'}
# MESH:C565842 {'type': 'Disease', 'mesh': 'MESH:C565842'}
# MESH:C565870 {'type': 'Disease', 'mesh': 'MESH:C565870'}
# MESH:C565898 {'type': 'Disease', 'mesh': 'MESH:C565898'}
# MESH:C565916 {'type': 'Disease', 'mesh': 'MESH:C565916'}
# MESH:C565942 {'type': 'Disease', 'mesh': 'MESH:C565942'}
# MESH:C565948 {'type': 'Disease', 'mesh': 'MESH:C565948'}
# MESH:C565957 {'type': 'Disease', 'mesh': 'MESH:C565957'}
# MESH:C565973 {'type': 'Disease', 'mesh': 'MESH:C565973'}
# MESH:C565974 {'type': 'Disease', 'mesh': 'MESH:C565974'}
# MESH:C566021 {'type': 'Disease', 'mesh': 'MESH:C566021'}
# MESH:C566023 {'type': 'Disease', 'mesh': 'MESH:C566023'}
# MESH:C566112 {'type': 'Disease', 'mesh': 'MESH:C566112'}
# MESH:C566121 {'type': 'Disease', 'mesh': 'MESH:C566121'}
# MESH:C566136 {'type': 'Disease', 'mesh': 'MESH:C566136'}
# MESH:C566162 {'type': 'Disease', 'mesh': 'MESH:C566162'}
# MESH:C566178 {'type': 'Disease', 'mesh': 'MESH:C566178'}
# MESH:C566273 {'type': 'Disease', 'mesh': 'MESH:C566273'}
# MESH:C566288 {'type': 'Disease', 'mesh': 'MESH:C566288'}
# MESH:C566291 {'type': 'Disease', 'mesh': 'MESH:C566291'}
# MESH:C566331 {'type': 'Disease', 'mesh': 'MESH:C566331'}
# MESH:C566333 {'type': 'Disease', 'mesh': 'MESH:C566333'}
# MESH:C566366 {'type': 'Disease', 'mesh': 'MESH:C566366'}
# MESH:C566367 {'type': 'Disease', 'mesh': 'MESH:C566367'}
# MESH:C566397 {'type': 'Disease', 'mesh': 'MESH:C566397'}
# MESH:C566403 {'type': 'Disease', 'mesh': 'MESH:C566403'}
# MESH:C566417 {'type': 'Disease', 'mesh': 'MESH:C566417'}
# MESH:C566449 {'type': 'Disease', 'mesh': 'MESH:C566449'}
# MESH:C566452 {'type': 'Disease', 'mesh': 'MESH:C566452'}
# MESH:C566454 {'type': 'Disease', 'mesh': 'MESH:C566454'}
# MESH:C566465 {'type': 'Disease', 'mesh': 'MESH:C566465'}
# MESH:C566476 {'type': 'Disease', 'mesh': 'MESH:C566476'}
# MESH:C566478 {'type': 'Disease', 'mesh': 'MESH:C566478'}
# MESH:C566504 {'type': 'Disease', 'mesh': 'MESH:C566504'}
# MESH:C566528 {'type': 'Disease', 'mesh': 'MESH:C566528'}
# MESH:C566555 {'type': 'Disease', 'mesh': 'MESH:C566555'}
# MESH:C566582 {'type': 'Disease', 'mesh': 'MESH:C566582'}
# MESH:C566593 {'type': 'Disease', 'mesh': 'MESH:C566593'}
# MESH:C566600 {'type': 'Disease', 'mesh': 'MESH:C566600'}
# MESH:C566618 {'type': 'Disease', 'mesh': 'MESH:C566618'}
# MESH:C566619 {'type': 'Disease', 'mesh': 'MESH:C566619'}
# MESH:C566719 {'type': 'Disease', 'mesh': 'MESH:C566719'}
# MESH:C566730 {'type': 'Disease', 'mesh': 'MESH:C566730'}
# MESH:C566766 {'type': 'Disease', 'mesh': 'MESH:C566766'}
# MESH:C566800 {'type': 'Disease', 'mesh': 'MESH:C566800'}
# MESH:C566801 {'type': 'Disease', 'mesh': 'MESH:C566801'}
# MESH:C566815 {'type': 'Disease', 'mesh': 'MESH:C566815'}
# MESH:C566822 {'type': 'Disease', 'mesh': 'MESH:C566822'}
# ...
# PA449969 {'type': 'Chemical', 'pgkb': 'PA449969'}
# PA449975 {'type': 'Chemical', 'pgkb': 'PA449975'}
# PA449977 {'type': 'Chemical', 'pgkb': 'PA449977'}
# PA450037 {'type': 'Chemical', 'pgkb': 'PA450037'}
# PA450039 {'type': 'Chemical', 'pgkb': 'PA450039'}
# PA450049 {'type': 'Drug', 'pgkb': 'PA450049'}
# PA450061 {'type': 'Drug', 'pgkb': 'PA450061'}
# PA450082 {'type': 'Drug', 'pgkb': 'PA450082'}
# PA450087 {'type': 'Chemical', 'pgkb': 'PA450087'}
# PA450106 {'type': 'Chemical', 'pgkb': 'PA450106'}
# PA450112 {'type': 'Chemical', 'pgkb': 'PA450112'}
# PA450125 {'type': 'Chemical', 'pgkb': 'PA450125'}
# PA450128 {'type': 'Drug', 'pgkb': 'PA450128'}
# PA450131 {'type': 'Drug', 'pgkb': 'PA450131'}
# PA450132 {'type': 'Chemical', 'pgkb': 'PA450132'}
# PA450133 {'type': 'Drug', 'pgkb': 'PA450133'}
# PA450137 {'type': 'Chemical', 'pgkb': 'PA450137'}
# PA450144 {'type': 'Chemical', 'pgkb': 'PA450144'}
# PA450146 {'type': 'Chemical', 'pgkb': 'PA450146'}
# PA450149 {'type': 'Drug', 'pgkb': 'PA450149'}
# PA450150 {'type': 'Chemical', 'pgkb': 'PA450150'}
# PA450152 {'type': 'Drug', 'pgkb': 'PA450152'}
# PA450154 {'type': 'Drug', 'pgkb': 'PA450154'}
# PA450163 {'type': 'Chemical', 'pgkb': 'PA450163'}
# PA450195 {'type': 'Drug', 'pgkb': 'PA450195'}
# PA450197 {'type': 'Drug', 'pgkb': 'PA450197'}
# PA450198 {'type': 'Chemical', 'pgkb': 'PA450198'}
# PA450205 {'type': 'Chemical', 'pgkb': 'PA450205'}
# PA450213 {'type': 'Chemical', 'pgkb': 'PA450213'}
# PA450214 {'type': 'Chemical', 'pgkb': 'PA450214'}
# PA450218 {'type': 'Chemical', 'pgkb': 'PA450218'}
# PA450221 {'type': 'Chemical', 'pgkb': 'PA450221'}
# PA450239 {'type': 'Drug', 'pgkb': 'PA450239'}
# PA450242 {'type': 'Chemical', 'pgkb': 'PA450242'}
# PA450243 {'type': 'Chemical', 'pgkb': 'PA450243'}
# PA450262 {'type': 'Chemical', 'pgkb': 'PA450262'}
# PA450266 {'type': 'Drug', 'pgkb': 'PA450266'}
# PA450267 {'type': 'Chemical', 'pgkb': 'PA450267'}
# PA450272 {'type': 'Chemical', 'pgkb': 'PA450272'}
# PA450273 {'type': 'Drug', 'pgkb': 'PA450273'}
# PA450320 {'type': 'Drug', 'pgkb': 'PA450320'}
# PA450322 {'type': 'Chemical', 'pgkb': 'PA450322'}
# PA450326 {'type': 'Drug', 'pgkb': 'PA450326'}
# PA450334 {'type': 'Drug', 'pgkb': 'PA450334'}
# PA450336 {'type': 'Drug', 'pgkb': 'PA450336'}
# PA450338 {'type': 'Drug', 'pgkb': 'PA450338'}
# PA450344 {'type': 'Chemical', 'pgkb': 'PA450344'}
# PA450348 {'type': 'Chemical', 'pgkb': 'PA450348'}
# PA450354 {'type': 'Chemical', 'pgkb': 'PA450354'}
# PA450369 {'type': 'Chemical', 'pgkb': 'PA450369'}
# PA450373 {'type': 'Chemical', 'pgkb': 'PA450373'}
# PA450374 {'type': 'Chemical', 'pgkb': 'PA450374'}
# PA450377 {'type': 'Drug', 'pgkb': 'PA450377'}
# PA450379 {'type': 'Chemical', 'pgkb': 'PA450379'}
# PA450384 {'type': 'Chemical', 'pgkb': 'PA450384'}
# PA450385 {'type': 'Drug', 'pgkb': 'PA450385'}
# PA450390 {'type': 'Drug', 'pgkb': 'PA450390'}
# PA450395 {'type': 'Chemical', 'pgkb': 'PA450395'}
# PA450398 {'type': 'Chemical', 'pgkb': 'PA450398'}
# PA450401 {'type': 'Chemical', 'pgkb': 'PA450401'}
# PA450403 {'type': 'Chemical', 'pgkb': 'PA450403'}
# PA450413 {'type': 'Chemical', 'pgkb': 'PA450413'}
# PA450422 {'type': 'Chemical', 'pgkb': 'PA450422'}
# PA450423 {'type': 'Chemical', 'pgkb': 'PA450423'}
# PA450428 {'type': 'Chemical', 'pgkb': 'PA450428'}
# PA450431 {'type': 'Drug', 'pgkb': 'PA450431'}
# PA450433 {'type': 'Chemical', 'pgkb': 'PA450433'}
# PA450434 {'type': 'Chemical', 'pgkb': 'PA450434'}
# PA450457 {'type': 'Chemical', 'pgkb': 'PA450457'}
# PA450461 {'type': 'Drug', 'pgkb': 'PA450461'}
# PA450464 {'type': 'Chemical', 'pgkb': 'PA450464'}
# PA450466 {'type': 'Chemical', 'pgkb': 'PA450466'}
# PA450475 {'type': 'Chemical', 'pgkb': 'PA450475'}
# PA450484 {'type': 'Drug', 'pgkb': 'PA450484'}
# PA450486 {'type': 'Drug', 'pgkb': 'PA450486'}
# PA450487 {'type': 'Drug', 'pgkb': 'PA450487'}
# PA450488 {'type': 'Chemical', 'pgkb': 'PA450488'}
# PA450492 {'type': 'Drug', 'pgkb': 'PA450492'}
# PA450496 {'type': 'Chemical', 'pgkb': 'PA450496'}
# PA450519 {'type': 'Chemical', 'pgkb': 'PA450519'}
# PA450521 {'type': 'Drug', 'pgkb': 'PA450521'}
# PA450524 {'type': 'Drug', 'pgkb': 'PA450524'}
# PA450526 {'type': 'Chemical', 'pgkb': 'PA450526'}
# PA450536 {'type': 'Drug', 'pgkb': 'PA450536'}
# PA450573 {'type': 'Chemical', 'pgkb': 'PA450573'}
# PA450576 {'type': 'Drug', 'pgkb': 'PA450576'}
# PA450586 {'type': 'Chemical', 'pgkb': 'PA450586'}
# PA450588 {'type': 'Chemical', 'pgkb': 'PA450588'}
# PA450595 {'type': 'Chemical', 'pgkb': 'PA450595'}
# PA450600 {'type': 'Chemical', 'pgkb': 'PA450600'}
# PA450601 {'type': 'Chemical', 'pgkb': 'PA450601'}
# PA450606 {'type': 'Chemical', 'pgkb': 'PA450606'}
# PA450611 {'type': 'Drug', 'pgkb': 'PA450611'}
# PA450616 {'type': 'Chemical', 'pgkb': 'PA450616'}
# PA450620 {'type': 'Drug', 'pgkb': 'PA450620'}
# PA450631 {'type': 'Chemical', 'pgkb': 'PA450631'}
# PA450633 {'type': 'Drug', 'pgkb': 'PA450633'}
# PA450636 {'type': 'Drug', 'pgkb': 'PA450636'}
# PA450640 {'type': 'Chemical', 'pgkb': 'PA450640'}
# PA450643 {'type': 'Drug', 'pgkb': 'PA450643'}
# PA450645 {'type': 'Chemical', 'pgkb': 'PA450645'}
# PA450648 {'type': 'Drug', 'pgkb': 'PA450648'}
# PA450649 {'type': 'Chemical', 'pgkb': 'PA450649'}
# PA450654 {'type': 'Drug', 'pgkb': 'PA450654'}
# PA450657 {'type': 'Chemical', 'pgkb': 'PA450657'}
# PA450666 {'type': 'Drug', 'pgkb': 'PA450666'}
# PA450678 {'type': 'Drug', 'pgkb': 'PA450678'}
# PA450684 {'type': 'Drug', 'pgkb': 'PA450684'}
# PA450702 {'type': 'Chemical', 'pgkb': 'PA450702'}
# PA450704 {'type': 'Chemical', 'pgkb': 'PA450704'}
# PA450705 {'type': 'Chemical', 'pgkb': 'PA450705'}
# PA450715 {'type': 'Drug', 'pgkb': 'PA450715'}
# PA450721 {'type': 'Chemical', 'pgkb': 'PA450721'}
# PA450725 {'type': 'Drug', 'pgkb': 'PA450725'}
# PA450731 {'type': 'Chemical', 'pgkb': 'PA450731'}
# PA450741 {'type': 'Chemical', 'pgkb': 'PA450741'}
# PA450744 {'type': 'Drug', 'pgkb': 'PA450744'}
# PA450748 {'type': 'Chemical', 'pgkb': 'PA450748'}
# PA450757 {'type': 'Drug', 'pgkb': 'PA450757'}
# PA450761 {'type': 'Chemical', 'pgkb': 'PA450761'}
# PA450771 {'type': 'Drug', 'pgkb': 'PA450771'}
# PA450778 {'type': 'Drug', 'pgkb': 'PA450778'}
# PA450790 {'type': 'Drug', 'pgkb': 'PA450790'}
# PA450797 {'type': 'Drug', 'pgkb': 'PA450797'}
# PA450801 {'type': 'Chemical', 'pgkb': 'PA450801'}
# PA450836 {'type': 'Drug', 'pgkb': 'PA450836'}
# PA450840 {'type': 'Drug', 'pgkb': 'PA450840'}
# PA450849 {'type': 'Drug', 'pgkb': 'PA450849'}
# PA450850 {'type': 'Drug', 'pgkb': 'PA450850'}
# PA450859 {'type': 'Drug', 'pgkb': 'PA450859'}
# PA450863 {'type': 'Drug', 'pgkb': 'PA450863'}
# PA450864 {'type': 'Drug', 'pgkb': 'PA450864'}
# PA450873 {'type': 'Drug', 'pgkb': 'PA450873'}
# PA450877 {'type': 'Chemical', 'pgkb': 'PA450877'}
# PA450882 {'type': 'Chemical', 'pgkb': 'PA450882'}
# PA450897 {'type': 'Drug', 'pgkb': 'PA450897'}
# PA450903 {'type': 'Drug', 'pgkb': 'PA450903'}
# PA450911 {'type': 'Chemical', 'pgkb': 'PA450911'}
# PA450913 {'type': 'Drug', 'pgkb': 'PA450913'}
# PA450919 {'type': 'Drug', 'pgkb': 'PA450919'}
# PA450921 {'type': 'Chemical', 'pgkb': 'PA450921'}
# PA450926 {'type': 'Drug', 'pgkb': 'PA450926'}
# PA450931 {'type': 'Drug', 'pgkb': 'PA450931'}
# PA450932 {'type': 'Chemical', 'pgkb': 'PA450932'}
# PA450935 {'type': 'Chemical', 'pgkb': 'PA450935'}
# PA450952 {'type': 'Drug', 'pgkb': 'PA450952'}
# PA450954 {'type': 'Drug', 'pgkb': 'PA450954'}
# PA450957 {'type': 'Drug', 'pgkb': 'PA450957'}
# PA450962 {'type': 'Chemical', 'pgkb': 'PA450962'}
# PA450965 {'type': 'Chemical', 'pgkb': 'PA450965'}
# PA450975 {'type': 'Drug', 'pgkb': 'PA450975'}
# PA450985 {'type': 'Chemical', 'pgkb': 'PA450985'}
# PA450993 {'type': 'Drug', 'pgkb': 'PA450993'}
# PA451047 {'type': 'Drug', 'pgkb': 'PA451047'}
# PA451089 {'type': 'Chemical', 'pgkb': 'PA451089'}
# PA451093 {'type': 'Chemical', 'pgkb': 'PA451093'}
# PA451096 {'type': 'Chemical', 'pgkb': 'PA451096'}
# PA451100 {'type': 'Chemical', 'pgkb': 'PA451100'}
# PA451101 {'type': 'Drug', 'pgkb': 'PA451101'}
# PA451103 {'type': 'Chemical', 'pgkb': 'PA451103'}
# PA451105 {'type': 'Chemical', 'pgkb': 'PA451105'}
# PA451106 {'type': 'Chemical', 'pgkb': 'PA451106'}
# PA451107 {'type': 'Drug', 'pgkb': 'PA451107'}
# PA451108 {'type': 'Drug', 'pgkb': 'PA451108'}
# PA451110 {'type': 'Drug', 'pgkb': 'PA451110'}
# PA451112 {'type': 'Chemical', 'pgkb': 'PA451112'}
# PA451114 {'type': 'Drug', 'pgkb': 'PA451114'}
# PA451124 {'type': 'Chemical', 'pgkb': 'PA451124'}
# PA451125 {'type': 'Drug', 'pgkb': 'PA451125'}
# PA451128 {'type': 'Chemical', 'pgkb': 'PA451128'}
# PA451131 {'type': 'Chemical', 'pgkb': 'PA451131'}
# PA451140 {'type': 'Chemical', 'pgkb': 'PA451140'}
# PA451141 {'type': 'Chemical', 'pgkb': 'PA451141'}
# PA451142 {'type': 'Drug', 'pgkb': 'PA451142'}
# PA451156 {'type': 'Chemical', 'pgkb': 'PA451156'}
# PA451159 {'type': 'Chemical', 'pgkb': 'PA451159'}
# PA451170 {'type': 'Drug', 'pgkb': 'PA451170'}
# PA451182 {'type': 'Chemical', 'pgkb': 'PA451182'}
# PA451185 {'type': 'Drug', 'pgkb': 'PA451185'}
# PA451193 {'type': 'Chemical', 'pgkb': 'PA451193'}
# PA451213 {'type': 'Chemical', 'pgkb': 'PA451213'}
# PA451221 {'type': 'Chemical', 'pgkb': 'PA451221'}
# PA451223 {'type': 'Chemical', 'pgkb': 'PA451223'}
# PA451224 {'type': 'Chemical', 'pgkb': 'PA451224'}
# PA451236 {'type': 'Drug', 'pgkb': 'PA451236'}
# PA451241 {'type': 'Chemical', 'pgkb': 'PA451241'}
# PA451249 {'type': 'Drug', 'pgkb': 'PA451249'}
# PA451250 {'type': 'Chemical', 'pgkb': 'PA451250'}
# PA451251 {'type': 'Drug', 'pgkb': 'PA451251'}
# PA451257 {'type': 'Chemical', 'pgkb': 'PA451257'}
# PA451258 {'type': 'Chemical', 'pgkb': 'PA451258'}
# PA451260 {'type': 'Chemical', 'pgkb': 'PA451260'}
# PA451261 {'type': 'Chemical', 'pgkb': 'PA451261'}
# PA451271 {'type': 'Drug', 'pgkb': 'PA451271'}
# PA451299 {'type': 'Chemical', 'pgkb': 'PA451299'}
# PA451305 {'type': 'Drug', 'pgkb': 'PA451305'}
# PA451308 {'type': 'Drug', 'pgkb': 'PA451308'}
# PA451316 {'type': 'Chemical', 'pgkb': 'PA451316'}
# PA451333 {'type': 'Chemical', 'pgkb': 'PA451333'}
# PA451363 {'type': 'Chemical', 'pgkb': 'PA451363'}
# PA451365 {'type': 'Chemical', 'pgkb': 'PA451365'}
# PA451406 {'type': 'Chemical', 'pgkb': 'PA451406'}
# PA451446 {'type': 'Chemical', 'pgkb': 'PA451446'}
# PA451455 {'type': 'Drug', 'pgkb': 'PA451455'}
# PA451457 {'type': 'Chemical', 'pgkb': 'PA451457'}
# PA451483 {'type': 'Chemical', 'pgkb': 'PA451483'}
# PA451492 {'type': 'Drug', 'pgkb': 'PA451492'}
# PA451494 {'type': 'Chemical', 'pgkb': 'PA451494'}
# PA451512 {'type': 'Chemical', 'pgkb': 'PA451512'}
# PA451514 {'type': 'Drug', 'pgkb': 'PA451514'}
# PA451521 {'type': 'Drug', 'pgkb': 'PA451521'}
# PA451522 {'type': 'Chemical', 'pgkb': 'PA451522'}
# PA451524 {'type': 'Drug', 'pgkb': 'PA451524'}
# PA451527 {'type': 'Drug', 'pgkb': 'PA451527'}
# PA451529 {'type': 'Drug', 'pgkb': 'PA451529'}
# PA451536 {'type': 'Drug', 'pgkb': 'PA451536'}
# PA451539 {'type': 'Chemical', 'pgkb': 'PA451539'}
# PA451540 {'type': 'Chemical', 'pgkb': 'PA451540'}
# PA451542 {'type': 'Chemical', 'pgkb': 'PA451542'}
# PA451544 {'type': 'Chemical', 'pgkb': 'PA451544'}
# PA451547 {'type': 'Chemical', 'pgkb': 'PA451547'}
# PA451550 {'type': 'Chemical', 'pgkb': 'PA451550'}
# PA451558 {'type': 'Drug', 'pgkb': 'PA451558'}
# PA451565 {'type': 'Chemical', 'pgkb': 'PA451565'}
# PA451566 {'type': 'Chemical', 'pgkb': 'PA451566'}
# PA451576 {'type': 'Drug', 'pgkb': 'PA451576'}
# PA451578 {'type': 'Chemical', 'pgkb': 'PA451578'}
# PA451581 {'type': 'Chemical', 'pgkb': 'PA451581'}
# PA451590 {'type': 'Drug', 'pgkb': 'PA451590'}
# PA451608 {'type': 'Drug', 'pgkb': 'PA451608'}
# PA451611 {'type': 'Chemical', 'pgkb': 'PA451611'}
# PA451612 {'type': 'Drug', 'pgkb': 'PA451612'}
# PA451616 {'type': 'Chemical', 'pgkb': 'PA451616'}
# PA451620 {'type': 'Drug', 'pgkb': 'PA451620'}
# PA451627 {'type': 'Chemical', 'pgkb': 'PA451627'}
# PA451632 {'type': 'Chemical', 'pgkb': 'PA451632'}
# PA451638 {'type': 'Drug', 'pgkb': 'PA451638'}
# PA451640 {'type': 'Drug', 'pgkb': 'PA451640'}
# PA451644 {'type': 'Chemical', 'pgkb': 'PA451644'}
# PA451646 {'type': 'Chemical', 'pgkb': 'PA451646'}
# PA451663 {'type': 'Chemical', 'pgkb': 'PA451663'}
# PA451664 {'type': 'Drug', 'pgkb': 'PA451664'}
# PA451666 {'type': 'Chemical', 'pgkb': 'PA451666'}
# PA451668 {'type': 'Chemical', 'pgkb': 'PA451668'}
# PA451669 {'type': 'Drug', 'pgkb': 'PA451669'}
# PA451673 {'type': 'Drug', 'pgkb': 'PA451673'}
# PA451674 {'type': 'Drug', 'pgkb': 'PA451674'}
# PA451684 {'type': 'Drug', 'pgkb': 'PA451684'}
# PA451686 {'type': 'Chemical', 'pgkb': 'PA451686'}
# PA451690 {'type': 'Chemical', 'pgkb': 'PA451690'}
# PA451704 {'type': 'Chemical', 'pgkb': 'PA451704'}
# PA451718 {'type': 'Chemical', 'pgkb': 'PA451718'}
# PA451721 {'type': 'Drug', 'pgkb': 'PA451721'}
# PA451729 {'type': 'Chemical', 'pgkb': 'PA451729'}
# PA451731 {'type': 'Drug', 'pgkb': 'PA451731'}
# PA451735 {'type': 'Chemical', 'pgkb': 'PA451735'}
# PA451741 {'type': 'Chemical', 'pgkb': 'PA451741'}
# PA451743 {'type': 'Chemical', 'pgkb': 'PA451743'}
# PA451744 {'type': 'Chemical', 'pgkb': 'PA451744'}
# PA451746 {'type': 'Drug', 'pgkb': 'PA451746'}
# PA451749 {'type': 'Chemical', 'pgkb': 'PA451749'}
# PA451752 {'type': 'Chemical', 'pgkb': 'PA451752'}
# PA451753 {'type': 'Drug', 'pgkb': 'PA451753'}
# PA451773 {'type': 'Drug', 'pgkb': 'PA451773'}
# PA451775 {'type': 'Chemical', 'pgkb': 'PA451775'}
# PA451776 {'type': 'Chemical', 'pgkb': 'PA451776'}
# PA451784 {'type': 'Drug', 'pgkb': 'PA451784'}
# PA451788 {'type': 'Chemical', 'pgkb': 'PA451788'}
# PA451791 {'type': 'Chemical', 'pgkb': 'PA451791'}
# PA451802 {'type': 'Drug', 'pgkb': 'PA451802'}
# PA451806 {'type': 'Drug', 'pgkb': 'PA451806'}
# PA451811 {'type': 'Drug', 'pgkb': 'PA451811'}
# PA451822 {'type': 'Drug', 'pgkb': 'PA451822'}
# PA451831 {'type': 'Drug', 'pgkb': 'PA451831'}
# PA451835 {'type': 'Chemical', 'pgkb': 'PA451835'}
# PA451836 {'type': 'Drug', 'pgkb': 'PA451836'}
# PA451843 {'type': 'Drug', 'pgkb': 'PA451843'}
# PA451846 {'type': 'Chemical', 'pgkb': 'PA451846'}
# PA451850 {'type': 'Chemical', 'pgkb': 'PA451850'}
# PA451852 {'type': 'Drug', 'pgkb': 'PA451852'}
# PA451858 {'type': 'Drug', 'pgkb': 'PA451858'}
# PA451868 {'type': 'Chemical', 'pgkb': 'PA451868'}
# PA451877 {'type': 'Chemical', 'pgkb': 'PA451877'}
# PA451879 {'type': 'Chemical', 'pgkb': 'PA451879'}
# PA451892 {'type': 'Chemical', 'pgkb': 'PA451892'}
# PA451898 {'type': 'Chemical', 'pgkb': 'PA451898'}
# PA451899 {'type': 'Chemical', 'pgkb': 'PA451899'}
# PA451900 {'type': 'Chemical', 'pgkb': 'PA451900'}
# PA451906 {'type': 'Chemical', 'pgkb': 'PA451906'}
# PA451935 {'type': 'Drug', 'pgkb': 'PA451935'}
# PA451938 {'type': 'Drug', 'pgkb': 'PA451938'}
# PA451946 {'type': 'Drug', 'pgkb': 'PA451946'}
# PA451950 {'type': 'Drug', 'pgkb': 'PA451950'}
# PA451954 {'type': 'Chemical', 'pgkb': 'PA451954'}
# PA451956 {'type': 'Drug', 'pgkb': 'PA451956'}
# PA451961 {'type': 'Chemical', 'pgkb': 'PA451961'}
# PA451991 {'type': 'Chemical', 'pgkb': 'PA451991'}
# PA451996 {'type': 'Chemical', 'pgkb': 'PA451996'}
# PA451999 {'type': 'Chemical', 'pgkb': 'PA451999'}
# PA452167 {'type': 'Chemical', 'pgkb': 'PA452167'}
# PA452229 {'type': 'Chemical', 'pgkb': 'PA452229'}
# PA452233 {'type': 'Chemical', 'pgkb': 'PA452233'}
# PA452249 {'type': 'Chemical', 'pgkb': 'PA452249'}
# PA452347 {'type': 'Chemical', 'pgkb': 'PA452347'}
# PA452604 {'type': 'Chemical', 'pgkb': 'PA452604'}
# PA452606 {'type': 'Drug', 'pgkb': 'PA452606'}
# PA452610 {'type': 'Chemical', 'pgkb': 'PA452610'}
# PA452614 {'type': 'Drug', 'pgkb': 'PA452614'}
# PA452615 {'type': 'Chemical', 'pgkb': 'PA452615'}
# PA452616 {'type': 'Chemical', 'pgkb': 'PA452616'}
# PA452618 {'type': 'Chemical', 'pgkb': 'PA452618'}
# PA452619 {'type': 'Chemical', 'pgkb': 'PA452619'}
# PA452620 {'type': 'Chemical', 'pgkb': 'PA452620'}
# PA452621 {'type': 'Chemical', 'pgkb': 'PA452621'}
# PA452629 {'type': 'Chemical', 'pgkb': 'PA452629'}
# PA452631 {'type': 'Chemical', 'pgkb': 'PA452631'}
# PA452632 {'type': 'Chemical', 'pgkb': 'PA452632'}
# PA452633 {'type': 'Chemical', 'pgkb': 'PA452633'}
# PA452634 {'type': 'Chemical', 'pgkb': 'PA452634'}
# PA452637 {'type': 'Chemical', 'pgkb': 'PA452637'}
# PA452638 {'type': 'Chemical', 'pgkb': 'PA452638'}
# PA452639 {'type': 'Chemical', 'pgkb': 'PA452639'}
# PA452640 {'type': 'Chemical', 'pgkb': 'PA452640'}
# PA7001 {'type': 'Drug', 'pgkb': 'PA7001'}
# null:PA134946555 {'type': 'VariantLocation', 'ncbi': 'null:PA134946555'}
# null:PA33532 {'type': 'VariantLocation', 'ncbi': 'null:PA33532'}
# null:PA35845 {'type': 'VariantLocation', 'ncbi': 'null:PA35845'}
# null:PA38407 {'type': 'VariantLocation', 'ncbi': 'null:PA38407'}
# Total with aliases: 20393 / 29354

# %%
data["155060"]
# Out:
# {'type': 'Gene', 'ncbi': '155060'}

# %% [markdown]
# ### Add data to database

# %%
ALIASES_WRITE = '''INSERT OR IGNORE INTO {table} (
                {col1}, {col2}, {col3}, {col4}, {col5} )
                VALUES ( ? , ? , ? , ? , ? );'''.format(
            table = TABLE_NAME, 
            col1=MESH_VALUE,
            col2=PHARMGKB_VALUE,
            col3=NCBI_VALUE,
            col4=VALUES_COLUMN,
            col5=TYPE_COLUMN)

if '' in data:
    del data['']

for key in log_progress(data, every=1000, name="Added to DB"):
    try:
        values = data[key]
        values_str = json.dumps(values)
        values_type = values["type"]
        
        
        mesh_val = None
        pgkb_val = None
        ncbi_val = None
        
        if MESH_VALUE in values:
            mesh_val = values[MESH_VALUE]
        
        if PHARMGKB_VALUE in values:
            pgkb_val = values[PHARMGKB_VALUE]
            
        if NCBI_VALUE in values:
            ncbi_val = values[NCBI_VALUE]

    
        cursor_all.execute(ALIASES_WRITE,(mesh_val, pgkb_val, ncbi_val, values_str, values_type))        

    except Exception as e:
        print(key, values)
        raise e
if WRITE:
    conn_all.commit()
    
print("Data committed")

if WRITE:
    with open("all_aliases_for_mike.json", "w+") as file:
        file.write(json.dumps( data ))
        
print("file written")
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=29353)))
# Data committed
# file written
